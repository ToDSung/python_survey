# %%
#encoding=utf-8
import jieba
import jieba.analyse

jieba.set_dictionary('dict.txt.big')
with open('test.txt', 'r',encoding='UTF-8') as file:    
    

    #各行分詞
    
    for line in file:
        sentence=line.strip().lstrip('\ufeff')
        words= jieba.lcut(sentence, cut_all=False)
        print(words)
    """
    
    content=file.read()
    #TF-IDF

    for x,w in jieba.analyse.extract_tags(content, topK=20, withWeight=True, allowPOS=()):
        print('%s %s' % (x, w))
    print('='*40)

    #TextRANK
    for x, w in jieba.analyse.textrank(content, topK=20 ,withWeight=True):
        print('%s %s' % (x, w))
    
    """
# Out:
# Building prefix dict from C:\Users\wlunareve\python\dict.txt.big ...
# Loading model from cache C:\Users\WLUNAR~1\AppData\Local\Temp\jieba.ube0c4e67d291f94013d7023df2b3161e.cache
# Loading model cost 1.346 seconds.
# Prefix dict has been built succesfully.
# ['第一章', ' ', '車禍']
# []
# ['砰', '！']
# []
# ['全身', '骨架', '像是', '碎掉', '似的', '，', '難以忍受', '的', '疼痛', '傳遍', '全身', '，', '甦', '沐', '後背', '緊緊', '的', '貼', '著', '油漆', '馬路', '，', '滑', '出去', '老遠', '，', '額頭', '布滿', '著大顆', '大顆', '的', '汗珠', '，', '嘴里', '發出', '痛苦', '的', '倒', '抽氣']
# ['聲']
# []
# ['肋骨', '斷', '了', '！']
# []
# ['躺倒', '在', '地', '的', '瞬間', '，', '甦', '沐', '清楚', '的', '听到', '肋骨', '斷掉', '的', '聲音', '，', '鑽心', '的', '疼痛', '使', '他', '想要', '掙扎', '著站', '起', '，', '卻', '又', '沒有', '辦法', '動彈', '。']
# []
# ['“', '啊', '！', '甦', '沐', '，', '你', '沒事', '吧', '？', '”']
# []
# ['尖叫聲', '中', '被', '甦', '沐', '抱', '在', '懷中', '的', '一個', '女子', '扭過', '腦袋', '，', '渾然', '不顧', '散開', '的', '秀發', '，', '滿臉', '焦急', '的', '低頭', '喊道', '。']
# []
# ['“', '咳咳', '！', '”']
# []
# ['甦', '沐', '急喘著', '咳嗽', '了', '兩聲', '，', '露出', '一嘴', '潔白', '的', '牙齒', '，', '苦笑', '著道', '︰', '“', '還好', '，', '暫時', '死不了', '！', '不過', '葉大', '小姐', '，', '你', '要是', '再', '不', '起來', '的話', '，', '我', '恐怕', '就', '會', '被', '你', '壓死', '。', '”']
# []
# ['“', '啊', '！', '對不起', '！', '”']
# []
# ['葉惜', '急忙', '掙扎', '著', '從', '甦', '沐', '懷中', '站', '起', '，', '身穿', '一', '系', '白裙', '，', '面容', '姣好', '，', '氣質', '溫雅', '的', '她', '，', '失去', '了', '平常', '的', '冷靜', '，', '能', '做', '的', '除了', '著急', '還是', '著急', '。']
# []
# ['“', '我', '扶', '你', '起來', '！', '”']
# []
# ['“', '別動', '我', '！', '”', '甦', '沐', '急', '聲道', '︰', '“', '我', '的', '肋骨', '好像', '斷', '了', '，', '幫忙', '叫', '救護車', '。', '”']
# []
# ['“', '好', '，', '你', '等', '著', '！', '”', '葉惜', '瞧', '著', '甦', '沐', '額頭', '滴下', '的', '汗珠', '，', '急忙', '跑', '到', '馬路', '旁邊', '，', '著', '急忙', '慌', '的', '掏出', '手機', '便', '撥', '起', '電話', '。']
# []
# ['“', '甦', '沐', '，', '你', '再', '等', '會', '，', '很快', '救護車', '就', '來', '了', '！', '你', '可', '千萬', '不要', '出事', '！', '”', '葉惜', '真不知道', '應該', '怎麼', '形容', '現在', '著急', '的', '心情', '。']
# []
# ['“', '葉惜', '，', '我', '沒事', '，', '死不了', '！', '”', '甦', '沐', '故作', '瀟灑', '道', '。']
# []
# ['“', '就', '知道', '硬撐', '，', '你', '都', '這樣', '了', '還說', '沒事', '，', '是不是', '想要', '我', '擔心', '死', '那', '？', '甦', '沐', '，', '你', '放心', '，', '你', '要是', '有事', '的話', '，', '我', '絕對', '不會', '放過', '那個', '混蛋', '！', '”', '葉惜', '說', '這話', '的', '時候', '，', '臉上', '閃動', '著', '的', '那種', '堅毅', '執著', '是', '甦', '沐', '從來沒', '見過', '的', '。']
# []
# ['要', '知道', '甦', '沐', '和', '葉惜', '兩人', '的', '關系', '雖說', '沒有', '多鐵', '，', '但', '卻', '也', '絕對', '不算', '陌生', '。', '兩人', '都', '是', '江南', '大學', '經管院', '的', '學生', '，', '四年', '的', '大學', '生活', '，', '同在院', '學生會', '共事', '。', '雖然', '不是', '一個', '部', '，', '但', '彼此', '偶爾', '踫', '到', '也', '會', '說', '上', '兩句話', '。']
# []
# ['甦', '沐', '印象', '中', '的', '葉惜', '，', '屬于', '那種', '氣質', '高貴典雅', '，', '很', '為', '有', '教養', '，', '極少', '發脾氣', '的', '女孩', '。', '像是', '現在', '這樣', '憤怒', '，', '還是', '第一次', '見到', '。']
# []
# ['不過', '想必', '換成', '誰', '，', '遇到', '這事', '都', '沒', '辦法', '冷靜', '。']
# []
# ['要', '知道', '剛才', '如果', '不是', '甦', '沐', '恰好', '在', '旁邊', '，', '恰好', '認出', '是', '葉惜', '，', '又', '在', '最', '為', '危險', '的', '時候', '，', '出于', '本能', '而', '拼著', '性命', '，', '將葉惜', '從', '那輛', '直接', '急', '沖', '過來', '的', '車下', '救出', '的話', '，', '現在', '葉惜', '這條', '命', '已經', '丟掉', '。', '正值', '青春年華', '之時', '香消玉損', '，', '換誰都會', '瘋狂', '。']
# []
# ['葉惜', '能夠', '忍著', '沒', '沖', '過去', '，', '質問', '那個', '開車', '的', '家伙', '，', '已經', '是', '她', '的', '極限', '。']
# []
# ['“', '對', '了', '甦', '沐', '，', '你', '怎麼', '會', '在', '這里', '？', '”', '葉惜', '突然', '問道', '。']
# []
# ['“', '我', '怎麼', '會', '在', '這里', '？', '是', '啊', '，', '我', '要是', '沒有', '在', '這里', '的話', '，', '也', '不會', '受傷', '。', '不過', '葉大', '小姐', '，', '我還', '沒有', '問你為', '什麼', '會', '在', '這里', '，', '你', '卻', '主動', '問我', '了', '。', '”', '甦', '沐', '心底', '暗暗', '的', '苦笑', '著', '。']
# []
# ['甦', '沐', '就算', '再能', '想', '，', '都', '沒有', '想到', '過', '，', '大學畢業', '一年', '後', '第一次', '來', '盛京', '市', '，', '在', '母校', '旁邊', '的', '舊書', '市場', '轉悠', '，', '出來', '便', '會', '踫', '到', '這事', '。']
# []
# ['書', '？', '書', '那', '！', '甦', '沐', '想到', '這個', '，', '便', '有些', '著急', '的', '向', '著', '旁邊', '瞧', '去', '，', '果不其然', '剛才', '因為', '近乎', '本能', '的', '沖', '出去', '，', '一時', '沒有', '多想', '，', '便將', '那', '一厚沓', '子書', '扔掉', '，', '現在', '散落', '的', '滿地', '都', '是', '。', '陣陣', '清風', '吹過', '，', '吹動', '著書', '頁', '嘩啦', '作響', '。']
# []
# ['“', '葉惜', '，', '我', '的', '書', '...', '書', '...', '”']
# []
# ['甦', '沐', '掙扎', '著', '就', '想', '站', '起', '，', '但', '就', '在', '這時', '一股', '難以', '抵抗', '的', '疼痛', '忽然', '從', '後背', '傳來', '，', '瞬間', '他', '便', '昏迷', '過去', '。']
# []
# ['“', '甦', '沐', '，', '你', '不要', '嚇我', '！', '”', '葉惜', '大聲', '喊道', '，', '想', '踫', '甦', '沐', '卻', '又', '怕', '傷', '到', '他', '，', '不', '踫', '甦', '沐', '卻', '又', '昏迷', '過去', '，', '一時間', '她', '站', '在', '旁邊', '干著', '急', '沒', '辦法', '。']
# []
# ['還好', '沒有', '多久', '救護車', '便', '趕到', '，', '將', '甦', '沐', '很', '為', '小心', '的', '抬', '上車', '後', '，', '葉惜', '便', '跟', '著', '坐', '了', '上去', '，', '直到', '車開', '出去', '後', '，', '她', '懸著', '的', '心才', '算', '放松', '一些', '。', '隨後', '像是', '想到', '了', '什麼', '，', '連忙', '拿', '起', '手機', '，', '撥出', '號碼', '後', '沖', '著', '那邊', '只', '說', '了', '一句', '話', '便', '干脆', '的', '撂下', '。']
# []
# ['“', '我', '在', '江大', '前面', '被車撞', '了', '，', '現在', '正去', '市', '一院', '。', '”']
# []
# ['葉惜', '緊握', '著', '甦', '沐', '的', '手', '，', '瞧', '著', '眼前', '這張', '熟悉', '的', '不能', '再', '熟悉', '的', '臉蛋', '，', '心里', '面有', '道', '聲音', '急促', '的', '喊叫', '著', '。']
# []
# ['“', '甦', '沐', '，', '你', '可', '千萬', '不能', '出事', '，', '千萬', '不能', '！', '”']
# []
# ['剛才還', '亂哄哄', '的', '街道', '，', '這時', '已經', '恢復正常', '。', '滿地', '的', '舊書', '被', '風', '刮', '的', '到處', '都', '是', '，', '地面', '上', '那灘', '鮮血', '證明', '著剛', '才', '這里', '發生', '過', '一場', '車禍', '。']
# []
# ['而當', '所有人', '的', '注意力', '全都', '放在', '車禍', '身上', '的', '時候', '，', '任', '誰', '都', '沒有', '注意', '到', '，', '就', '在', '甦', '沐', '倒下', '鮮血', '流出', '的', '瞬間', '，', '原本', '身上', '斜', '跨', '著', '的', '書包', '內', '，', '安靜', '放著', '的', '一本', '古色古香', '的', '書', '，', '隨著', '鮮血', '的', '融入', '瞬息', '不見', '。']
# []
# ['盛京', '市', '第一', '人民', '醫院', '，', '重病', '監護室', '。']
# []
# ['甦', '沐', '從', '被', '送進來', '後', '，', '便', '一直', '處于', '昏迷', '狀態', '。', '原本', '醫院', '是', '沒想', '著將', '他', '安排', '到', '這里', '，', '畢竟', '只是', '一場', '車禍', '，', '而且', '這車', '禍', '明顯', '沒有', '撞', '到', '人', '。', '甦', '沐', '是', '救人', '的', '，', '就算', '斷', '了', '幾根', '骨頭', '，', '也', '早就', '給接', '好', '，', '安心', '休養', '就', '成', '。']
# []
# ['然而', '誰', '想到', '甦', '沐', '就是', '沒有', '醒來', '！']
# []
# ['這讓', '葉惜', '急壞', '了', '，', '在', '她', '的', '強烈要求', '下', '，', '甦', '沐', '住', '進', '了', '重病', '監護室', '。', '並且', '葉惜還', '發話', '，', '除非', '他', '醒來', '，', '不然', '絕對', '不能', '走', '出去', '半步', '。']
# []
# ['對此', '不以', '為然', '的', '醫院', '主治醫生', '，', '剛', '說出', '這不', '可能', '的', '時候', '，', '出現', '在', '葉惜', '身邊', '的', '人', '，', '只是', '向', '他', '亮出', '了', '工作證', '，', '他', '便', '臉色', '大變', '，', '想', '都', '沒想', '便', '安排', '好', '一切', '，', '並且', '保證', '24', '小時', '都', '在', '醫院', '內', '隨叫隨到', '。']
# []
# ['沒', '辦法', '，', '誰', '讓', '人家', '來頭', '太', '大', '！', '大到', '院長', '站', '在', '身邊', '，', '都', '不敢', '大', '喘氣', '。']
# []
# ['“', '小惜', '，', '這里', '我', '都', '安排', '好', '了', '，', '你', '就', '跟', '我', '回家吧', '！', '”']
# []
# ['此刻', '站', '在', '病房', '內', '說話', '的', '是', '一個', '男子', '，', '大約', '五十歲', '左右', '，', '穿著', '一身', '很為', '講究', '的', '衣服', '，', '五官', '宛如', '刀刻', '般', '稜', '角', '分明', '。', '即便', '是', '隨意', '的', '站', '在', '那里', '，', '身上', '散發', '出來', '的', '那股', '氣息', '，', '都', '讓', '人', '感到', '有種', '無法', '呼吸', '的', '窒息', '感', '，', '很', '顯然', '是', '久居', '上位', '養成', '的', '氣質', '。']
# []
# ['他', '便是', '葉惜', '的', '父親', '，', '葉', '安邦', '。']
# []
# ['“', '不', '！', '爸', '，', '甦', '沐', '是', '因為', '救', '我', '才', '受傷', '的', '，', '他', '現在', '人', '躺', '在', '病床', '上還', '沒有', '醒來', '，', '我', '怎麼', '能夠', '一走了之', '？', '我要', '陪', '在', '這里', '，', '直到', '他', '醒過來', '。', '”', '葉惜', '沉', '聲道', '。']
# []
# ['深知', '葉惜', '性格', '的', '葉', '安邦', '，', '知道', '自己', '這個', '寶貝女兒', '決定', '了', '的', '事', '，', '任憑', '自己', '再', '怎麼', '說', '都', '不會', '更改', '，', '他', '也', '便', '沒有', '強求', '。']
# []
# ['“', '那好', '，', '你', '想要', '在', '這里', '陪', '著', '的話', '就', '先', '陪', '著', '，', '等到', '我', '忙', '完', '再', '過來', '。', '”', '葉', '安邦', '說道', '。']
# []
# ['“', '爸', '，', '你', '去', '上班', '吧', '，', '我', '沒事', '！', '”', '葉惜', '扭頭', '微微一笑', '。']
# []
# ['“', '好', '！', '”', '葉', '安邦', '沒有', '多', '說', '什麼', '，', '直接', '走出', '病房', '。', '至于', '剩下', '的', '事', '，', '就算', '他', '不', '說', '，', '都', '會', '有人', '安排', '好', '的', '。']
# []
# ['“', '甦', '沐', '，', '你', '到底', '什麼', '時候', '才', '會', '醒來', '？', '”', '葉惜', '坐在', '床邊', '，', '盯', '著', '甦', '沐', '的', '臉', '喃喃', '道', '。']
# []
# ['江大', '四年', '，', '就算', '是', '葉惜', '最', '親密', '的', '閨蜜', '，', '都', '沒有', '誰知', '道', '在', '她', '心中', '，', '一直', '有著', '一個', '男子', '的', '身影', '，', '他', '便是', '甦', '沐', '。']
# []
# ['盡管', '甦', '沐', '不是', '什麼', '高官', '權貴', '，', '也', '沒有', '多少錢', '揮霍', '，', '但', '他', '那種', '不管', '任何', '時候', '做', '任何', '事', '都', '保持', '著', '的', '絕對', '自信', '，', '從來不', '因為', '出身', '不好', '而', '有', '任何', '自卑', '的', '坦然', '微笑', '，', '都', '深深', '的', '讓', '葉惜', '為', '之', '著迷', '。', '然而', '因為', '各種', '原因', '，', '直到', '畢業', '葉惜', '都', '沒有', '向', '甦', '沐', '表白', '。']
# []
# ['原本', '以為', '兩人', '不會', '再有', '交集', '，', '卻', '沒想到', '畢業', '一年', '後', '會', '以', '這樣', '的', '方式', '見面', '。', '這讓', '葉惜', '那顆', '沉寂', '的', '心', '，', '又', '開始', '活躍', '起來', '。']
# []
# ['葉惜', '現在', '只有', '一個', '念頭', '，', '祈求', '甦', '沐', '安然無恙', '的', '醒來', '。']
# []
# ['對', '這些', '根本', '不知情', '的', '甦', '沐', '，', '如今', '正處', '于', '水深火熱', '之中', '。', '他', '從', '被', '抬', '上', '救護車', '的', '那', '時候', '，', '便', '感覺', '有些', '不對勁', '。', '全身', '的', '血脈', '像是', '汽油', '點燃', '般', '，', '被', '灼燒', '的', '疼痛', '難忍', '。', '他', '按捺不住', '想要', '狂吼', '，', '但', '嗓子', '仿佛', '被', '什麼', '東西', '卡住', '似的', '，', '硬是', '喊', '不出', '一聲', '來', '。']
# []
# ['而且', '隱約', '中', '甦', '沐', '有種', '錯覺', '，', '他', '竟然', '能', '听到', '骨骼', '好像', '春筍', '破土', '般', '發出', '的', '那種', '清脆', '聲響', '。', '簡單', '的', '說', '，', '甦', '沐', '整具', '身子', '現在', '便是', '一個', '煉鋼爐', '，', '里面', '的', '所有', '細胞', '都', '在', '無形中', '被', '淬煉', '著', '。', '他', '不', '知道', '這是', '好事', '還是', '壞事', '，', '能', '做', '的', '除了', '咬緊牙關', '默默', '承受', '別無他法', '。']
# []
# ['轟', '！']
# []
# ['在', '燃燒', '著', '的', '血脈', '逐漸', '熄滅', '，', '甦', '沐', '感覺', '情況', '有些', '好轉', '的', '時候', '，', '腦海中', '轟', '的', '傳來', '一聲', '爆炸', '，', '隨即', '他', '詭異', '的', '發現', '，', '意識', '中', '竟然', '出現', '一道', '神秘', '的', '榜單', '。']
# []
# ['而', '在', '這道', '榜單', '最', '上方', '居中', '位置', '，', '赫然', '冒', '出', '兩個', '筆鋒', '強勁', '的', '篆體', '古字', '︰', '官榜', '！']
