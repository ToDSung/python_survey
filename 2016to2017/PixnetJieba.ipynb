# %%
import requests
import MySQLdb
from bs4 import BeautifulSoup
import jieba
import jieba.analyse

def remove_values_from_list(the_list, val):
    return [value for value in the_list if value != val]

def get_web_page(url): #原始地址
    time.sleep(0.5)  # 每次爬取前暫停 0.5 秒以免被 PTT 網站判定為大量惡意爬取
    resp = requests.get(
        url=url,
        cookies={'over18': '1'}
    )
    return resp.text

jieba.set_dictionary('dict.txt.big')
jieba.load_userdict('userdict.txt')

conn = MySQLdb.connect(host="localhost", user="root", passwd="", db="python",charset='utf8')#連結資料庫
cur = conn.cursor()
cur.execute("SELECT search_href,id FROM pixnet")
results = cur.fetchall()

with open('positive.txt', 'r',encoding='UTF-8') as positive:
    pos=[]
    for line in positive:
        pos.append(line.strip('\ufeff').strip())
    positive.close()

with open('nagative.txt', 'r',encoding='UTF-8') as nagative:
    nag=[]
    for line in nagative:
        nag.append(line.strip('\ufeff').strip())
    nagative.close()

with open('paid news.txt', 'r',encoding='UTF-8') as paidnews:
    paid=[]
    for line in paidnews:
        paid.append(line.strip('\ufeff').strip())
    paidnews.close()
    
print(pos)
print(nag)
print(paid)

pos_set=set(pos)
nag_set=set(nag)
paid_set=set(paid)

    
   
for record in results:    
    db_url = record[0]
    ixnet_id = record[1]
    res=requests.get(db_url)
    res.encoding='utf-8'
    soup = BeautifulSoup (res.text, "html5lib")
    soup2 =  soup.select('meta')[1]

    original_url =soup2['content'].lstrip('3;url=')

    print (original_url)

    res1=requests.get(original_url)
    res1.encoding='utf-8'
    soup1 = BeautifulSoup (res1.text, "html5lib")
    #內文
    main_article = soup1.select('.article-content-inner')    

    content=main_article[0].text.strip()
    sentence=content.split("\n")
    sentence=remove_values_from_list(sentence,'')

    total_pos_count=0
    total_nag_count=0
    total_paid_count=0
    for line in sentence:

        line2=line.strip()
        words=jieba.lcut(line2, cut_all=False)
        words_set = set(words)
        pos_intersection=words_set.intersection(pos_set)
        nag_intersection=words_set.intersection(nag_set)
        paid_intersection=words_set.intersection(paid_set)
        pos_count=len(pos_intersection)
        nag_count=len(nag_intersection)
        paid_count=len(paid_intersection)

        total_pos_count=total_pos_count+pos_count
        total_nag_count=total_nag_count+nag_count
        total_paid_count=total_paid_count+paid_count
    print(total_pos_count)
    print(total_nag_count)
    print(total_paid_count)
# Out:
# Building prefix dict from C:\Users\wlunareve\python\dict.txt.big ...
# Loading model from cache C:\Users\WLUNAR~1\AppData\Local\Temp\jieba.ube0c4e67d291f94013d7023df2b3161e.cache
# Loading model cost 1.420 seconds.
# Prefix dict has been built succesfully.
# ['超', '太', '真', '', '超美', '很美', '好美', '太大', '好大', '很大', '超大', '真大', '太好', '真好', '超好', '太便宜', '', '吸睛', '歐耶', '過癮', '齊全', '絕配', '極致', '享受', '滿足', '有感', '力推', '佛心', '浮誇', '心動', '對味', '幸福']
# ['不大', '不佳', '不優', '一般', '誠實', '老實', '普普', '普通', '不錯', '失望', '不推', '失落', '還行', '瑕疵', '斟酌']
# ['招待', '工商', '試用', '體驗', '愛評網', '推薦', '邀約', '免費', '分享']
# http://jesiarki.pixnet.net/blog/post/45500404
# 1
# 0
# 0
# http://luckykitty.pixnet.net/blog/post/43674835
# 0
# 0
# 1
# http://jinnic51345.pixnet.net/blog/post/39205595
# 1
# 0
# 0
# http://farmdirect01.pixnet.net/blog/post/300730922
# 0
# 0
# 0
# http://joyceliu9146.pixnet.net/blog/post/36916206-pepperoni-pizza-buns~pizza-麵包做法
# 0
# 0
# 0
# http://naomi0408.pixnet.net/blog/post/202744117-<麵團整型>辮子整型~變成可愛的麵包
# 1
# 0
# 0
# http://na0d0005.pixnet.net/blog/post/214518998
# 0
# 0
# 0
# http://ninaground.pixnet.net/blog/post/398023396-奶香濃的酒香葡萄乾杏仁奶酥餡
# 1
# 0
# 3
# http://s9902273.pixnet.net/blog/post/41550485
# 0
# 0
# 0
# http://sukioooru.pixnet.net/blog/post/285989557
# 0
# 0
# 0
# http://naomi0408.pixnet.net/blog/post/202743502-<麵團整型>菊花麵包整型~中式點心很適合的造
# 1
# 0
# 0
# http://t3design.pixnet.net/blog/post/100754539
# 0
# 0
# 2
# http://c31285.pixnet.net/blog/post/9917761
# 1
# 0
# 1
# http://joyceliu9146.pixnet.net/blog/post/182047743-nutella-&花生醬-聖誕樹麵包
# 1
# 0
# 0
# http://fw41688.pixnet.net/blog/post/204891544
# 2
# 0
# 0
# http://joyceliu9146.pixnet.net/blog/post/36927963-麵包碗(圓法)作法
# 1
# 0
# 0
# http://jesiarki.pixnet.net/blog/post/50418338
# 0
# 0
# 1
# http://yihui517.pixnet.net/blog/post/13478983
# 0
# 0
# 0
# http://naomi0408.pixnet.net/blog/post/202744921-<麵團整型>三丸子整型
# 2
# 0
# 0
# http://yida200623.pixnet.net/blog/post/324601509-{飲料}原萃---東方美人茶
# 0
# 0
# 0
# http://joyceliu9146.pixnet.net/blog/post/93582897-做麵包碗(圓法)來裝湯~~new-england-clam-chowder(巧
# 0
# 0
# 0
# http://reisei888.pixnet.net/blog/post/25969571
# 0
# 0
# 0
# http://sevenfishes7.pixnet.net/blog/post/174875403
# 1
# 0
# 0
# http://chioutian.pixnet.net/blog/post/398796748
# 1
# 0
# 0
# http://ninaground.pixnet.net/blog/post/395460976-不知會吃到那種餡的優格圓麵包
# 1
# 1
# 0
# http://jesiarki.pixnet.net/blog/post/54470204
# 0
# 0
# 1
# http://villagevilla.pixnet.net/blog/post/38655631
# 1
# 1
# 0
# http://workhome.pixnet.net/blog/post/190288806
# 0
# 0
# 0
# http://workhome.pixnet.net/blog/post/195058692
# 0
# 0
# 0
# http://b017292003.pixnet.net/blog/post/32434757
# 0
# 0
# 0
# http://ruianc.pixnet.net/blog/post/42165581
# 0
# 1
# 0
# http://beautydiy.pixnet.net/blog/post/31520388
# 0
# 0
# 0
# http://a643688.pixnet.net/blog/post/170194611
# 0
# 0
# 0
# http://apbb.pixnet.net/blog/post/41634035
# 0
# 0
# 0
# http://caleb243545.pixnet.net/blog/post/215695967
# 0
# 0
# 0
# http://lawg.pixnet.net/blog/post/69194118
# 0
# 0
# 1
# http://eat8185.pixnet.net/blog/post/33509729
# 2
# 0
# 0
# http://annyhuang.pixnet.net/blog/post/31567621
# 1
# 0
# 1
# http://mtrlk.pixnet.net/blog/post/14036212
# 1
# 0
# 0
# http://andrenomo.pixnet.net/blog/post/26627415
# 0
# 0
# 1
# http://carriemore2.pixnet.net/blog/post/30159355
# 0
# 0
# 0
# http://kenji7777.pixnet.net/blog/post/66734933
# 1
# 0
# 0
# http://cancer881881.pixnet.net/blog/post/115884077-癌症不是老人病!-1-3可預防
# 0
# 0
# 0
# http://cancer881881.pixnet.net/blog/post/142741148-如何鼓勵老人家抗癌？-耐心解說治療技術
# 0
# 0
# 0
# http://linea.pixnet.net/blog/post/31208045
# 1
# 4
# 0
# http://viola1007.pixnet.net/blog/post/9927800
# 1
# 0
# 0
# http://gold20317.pixnet.net/blog/post/20371517
# 0
# 0
# 0
# http://gbhtech.pixnet.net/blog/post/75412769
# 1
# 0
# 1
# http://smz20121215.pixnet.net/blog/post/40319695
# 1
# 0
# 0
# http://swt57502.pixnet.net/blog/post/305638
# 0
# 0
# 0
# http://kissinwang.pixnet.net/blog/post/36495049
# 2
# 0
# 0
# http://biohazard09o.pixnet.net/blog/post/36920493
# 0
# 0
# 2
# http://c55s55.pixnet.net/blog/post/12520341
# 0
# 0
# 0
# http://ufclark.pixnet.net/blog/post/5018665
# 0
# 0
# 0
# http://jason123455.pixnet.net/blog/post/200123244
# 9
# 0
# 1
# http://ndhu.pixnet.net/blog/post/31103431
# 0
# 0
# 0
# http://amy0404.pixnet.net/blog/post/195808851
# 15
# 2
# 3
# http://plugger.pixnet.net/blog/post/29167699
# 0
# 0
# 0
# http://plugger.pixnet.net/blog/post/29161705
# 0
# 0
# 0
# http://plugger.pixnet.net/blog/post/29229227
# 0
# 0
# 0
# http://olyflychen.pixnet.net/blog/post/245154128
# 3
# 2
# 2
# http://plugger.pixnet.net/blog/post/29184932
# 0
# 0
# 0
# http://hinlin.pixnet.net/blog/post/25242218
# 0
# 0
# 1
# http://flydog0527.pixnet.net/blog/post/87690287-♥【育兒大小識】你的寶寶會說話了嗎。寶寶
# 8
# 5
# 4
# http://k19980720.pixnet.net/blog/post/184353448-【123kubo-酷播】123kubo-看電影、看動漫、看連
# 0
# 1
# 1
# http://charlton343117tw.pixnet.net/blog/post/34441767
# 0
# 0
# 1
# http://time2011.pixnet.net/blog/post/95133086
# 1
# 9
# 1
# http://rs7822.pixnet.net/blog/post/1138660
# 0
# 0
# 0
# http://je235.pixnet.net/blog/post/4541073
# 0
# 0
# 0
# http://joe112.pixnet.net/blog/post/7923589
# 0
# 0
# 0
# http://alice41026.pixnet.net/blog/post/1396458
# 0
# 0
# 0
# http://peanut16.pixnet.net/blog/post/35845
# 0
# 0
# 0
# http://minimice.pixnet.net/blog/post/6535765
# 0
# 0
# 0
# http://nadia1990.pixnet.net/blog/post/176157865
# 0
# 0
# 0
# http://sunnycoconut.pixnet.net/blog/post/146645912
# 0
# 0
# 0
# http://yatingyo.pixnet.net/blog/post/1781040
# 0
# 0
# 0
# http://achu0125.pixnet.net/blog/post/14219820
# 0
# 0
# 0
# http://amy201006.pixnet.net/blog/post/34429729
# 0
# 0
# 0
# http://emma1213.pixnet.net/blog/post/22839153
# 0
# 0
# 0
# http://yj1.pixnet.net/blog/post/230900
# 0
# 0
# 0
# http://sweetkiala.pixnet.net/blog/post/10043266
# 0
# 0
# 0
# http://simple362store62.pixnet.net/blog/post/48368754
# 0
# 0
# 0
# http://ruianc.pixnet.net/blog/post/42165581
# 0
# 1
# 0
# http://beautydiy.pixnet.net/blog/post/31520388
# 0
# 0
# 0
# http://a643688.pixnet.net/blog/post/170194611
# 0
# 0
# 0
# http://apbb.pixnet.net/blog/post/41634035
# 0
# 0
# 0
# http://caleb243545.pixnet.net/blog/post/215695967
# 0
# 0
# 0
# http://lawg.pixnet.net/blog/post/69194118
# 0
# 0
# 1
# http://eat8185.pixnet.net/blog/post/33509729
# 2
# 0
# 0
# http://annyhuang.pixnet.net/blog/post/31567621
# 1
# 0
# 1
# http://mtrlk.pixnet.net/blog/post/14036212
# 1
# 0
# 0
# http://andrenomo.pixnet.net/blog/post/26627415
# 0
# 0
# 1
# http://carriemore2.pixnet.net/blog/post/30159355
# 0
# 0
# 0
# http://kenji7777.pixnet.net/blog/post/66734933
# 1
# 0
# 0
# http://cancer881881.pixnet.net/blog/post/115884077-癌症不是老人病!-1-3可預防
# 0
# 0
# 0
# http://cancer881881.pixnet.net/blog/post/142741148-如何鼓勵老人家抗癌？-耐心解說治療技術
# 0
# 0
# 0
# http://linea.pixnet.net/blog/post/31208045
# 1
# 4
# 0
# http://viola1007.pixnet.net/blog/post/9927800
# 1
# 0
# 0
# http://gold20317.pixnet.net/blog/post/20371517
# 0
# 0
# 0
# http://gbhtech.pixnet.net/blog/post/75412769
# 1
# 0
# 1
# http://smz20121215.pixnet.net/blog/post/40319695
# 1
# 0
# 0
# http://swt57502.pixnet.net/blog/post/305638
# 0
# 0
# 0
# http://kissinwang.pixnet.net/blog/post/36495049
# 2
# 0
# 0
# http://biohazard09o.pixnet.net/blog/post/36920493
# 0
# 0
# 2
# http://hero3507.pixnet.net/blog/post/200263497
# 1
# 0
# 2
# http://ao3ej3.pixnet.net/blog/post/5817550
# 1
# 1
# 2
# http://yahsing1017.pixnet.net/blog/post/2606279
# 0
# 1
# 1
# http://cy139.pixnet.net/blog/post/35176677
# 3
# 0
# 0
# http://jyuanhuang.pixnet.net/blog/post/221974712
# 0
# 0
# 0
# http://richpaul168.pixnet.net/blog/post/5301112
# 0
# 0
# 0
# http://ellecju.pixnet.net/blog/post/22076930
# 0
# 0
# 0
# http://leoliu1014.pixnet.net/blog/post/223054562
# 0
# 0
# 0
# http://rimiaaa.pixnet.net/blog/post/12678857
# 0
# 0
# 0
# http://fun7life.pixnet.net/blog/post/11817382
# 0
# 0
# 0
# http://fox9999.pixnet.net/blog/post/8691788
# 0
# 0
# 0
# http://dio5680.pixnet.net/blog/post/43437290-饗家2017年菜（下載表格http:--doora.qiniudn.com-pwog
# 0
# 0
# 0
# http://kennycorn.pixnet.net/blog/post/202183117
# 0
# 0
# 0
# http://caf708t.pixnet.net/blog/post/32013961
# 2
# 0
# 0
# http://t03ao04.pixnet.net/blog/post/25833437
# 0
# 0
# 1
# http://nantes.pixnet.net/blog/post/8881346
# 0
# 0
# 0
# http://leoliu1014.pixnet.net/blog/post/223066046
# 0
# 0
# 0
# http://bandfshipper.pixnet.net/blog/post/281015
# 0
# 0
# 0
# http://c55s55.pixnet.net/blog/post/12520341
# 0
# 0
# 0
# http://ufclark.pixnet.net/blog/post/5018665
# 0
# 0
# 0
# http://jason123455.pixnet.net/blog/post/200123244
# 9
# 0
# 1
# http://ndhu.pixnet.net/blog/post/31103431
# 0
# 0
# 0
# http://amy0404.pixnet.net/blog/post/195808851
# 15
# 2
# 3
# http://plugger.pixnet.net/blog/post/29167699
# 0
# 0
# 0
# http://plugger.pixnet.net/blog/post/29161705
# 0
# 0
# 0
# http://plugger.pixnet.net/blog/post/29229227
# 0
# 0
# 0
# http://olyflychen.pixnet.net/blog/post/245154128
# 3
# 2
# 2
# http://plugger.pixnet.net/blog/post/29184932
# 0
# 0
# 0
# http://hinlin.pixnet.net/blog/post/25242218
# 0
# 0
# 1
# http://flydog0527.pixnet.net/blog/post/87690287-♥【育兒大小識】你的寶寶會說話了嗎。寶寶
# 8
# 5
# 4
# http://k19980720.pixnet.net/blog/post/184353448-【123kubo-酷播】123kubo-看電影、看動漫、看連
# 0
# 1
# 1
# http://charlton343117tw.pixnet.net/blog/post/34441767
# 0
# 0
# 1
# http://time2011.pixnet.net/blog/post/95133086
# 1
# 9
# 1
# http://rs7822.pixnet.net/blog/post/1138660
# 0
# 0
# 0
# http://je235.pixnet.net/blog/post/4541073
# 0
# 0
# 0
# http://joe112.pixnet.net/blog/post/7923589
# 0
# 0
# 0
# http://alice41026.pixnet.net/blog/post/1396458
# 0
# 0
# 0
# http://peanut16.pixnet.net/blog/post/35845
# 0
# 0
# 0
# http://minimice.pixnet.net/blog/post/6535765
# 0
# 0
# 0
# http://nadia1990.pixnet.net/blog/post/176157865
# 0
# 0
# 0
# http://sunnycoconut.pixnet.net/blog/post/146645912
# 0
# 0
# 0
# http://yatingyo.pixnet.net/blog/post/1781040
# 0
# 0
# 0
# http://achu0125.pixnet.net/blog/post/14219820
# 0
# 0
# 0
# http://amy201006.pixnet.net/blog/post/34429729
# 0
# 0
# 0
# http://emma1213.pixnet.net/blog/post/22839153
# 0
# 0
# 0
# http://yj1.pixnet.net/blog/post/230900
# 0
# 0
# 0
# http://sweetkiala.pixnet.net/blog/post/10043266
# 0
# 0
# 0
# http://simple362store62.pixnet.net/blog/post/48368754
# 0
# 0
# 0
# http://bigbigtree.pixnet.net/blog/post/22275828
# 1
# 0
# 0
# http://www0913930868.pixnet.net/blog/post/303647981
# 0
# 0
# 0
# http://julia5168.pixnet.net/blog/post/43526806
# 0
# 1
# 1
# http://puzzleholic.pixnet.net/blog/post/44802371
# 0
# 2
# 1
# http://ctspon.pixnet.net/blog/post/227380414-胖子小吃部八德店
# 0
# 0
# 1
# http://changnina142.pixnet.net/blog/post/25947075-節食不運動輕熟女成瘦胖子
# 0
# 1
# 0
# http://comparelady.pixnet.net/blog/post/80431736-【台北比較姐】減肥陷阱百百種-你最容易深
# 1
# 0
# 2
# http://kima999999.pixnet.net/blog/post/188482827
# 2
# 0
# 0
# http://netvibes.pixnet.net/blog/post/64749669
# 0
# 0
# 0
# http://backsnow.pixnet.net/blog/post/3932712
# 2
# 0
# 0
# http://caleb243545.pixnet.net/blog/post/215695967
# 0
# 0
# 0
# http://a7825525.pixnet.net/blog/post/393355844
# 0
# 0
# 0
# http://tr7ift.pixnet.net/blog/post/107437181
# 0
# 0
# 1
# http://apple2345.pixnet.net/blog/post/7627162
# 0
# 0
# 0
# http://uba.pixnet.net/blog/post/16019351
# 0
# 0
# 0
# http://uba.pixnet.net/blog/post/14457553
# 0
# 0
# 0
# http://ftvsuperstar.pixnet.net/blog/post/32717926
# 0
# 0
# 0
# http://renemangrove.pixnet.net/blog/post/25181694
# 1
# 0
# 0
# http://uba.pixnet.net/blog/post/14838268
# 0
# 0
# 0
# http://uba.pixnet.net/blog/post/14718519
# 0
# 0
# 0
# http://uba.pixnet.net/blog/post/15462164
# 0
# 0
# 0
# http://uba.pixnet.net/blog/post/15282856
# 0
# 0
# 0
# http://uba.pixnet.net/blog/post/14717286
# 0
# 0
# 0
# http://uba.pixnet.net/blog/post/14926288
# 0
# 0
# 0
# http://uba.pixnet.net/blog/post/14963065
# 0
# 0
# 0
# http://uba.pixnet.net/blog/post/14881552
# 0
# 0
# 0
# http://melodtw.pixnet.net/blog/post/12524917
# 1
# 0
# 0
# http://wantsunny.pixnet.net/blog/post/62959829
# 2
# 2
# 1
# http://pentiumto.pixnet.net/blog/post/47370629
# 0
# 0
# 0
# http://pentiumto.pixnet.net/blog/post/47370471
# 0
# 0
# 1
# http://quantum2nd.pixnet.net/blog/post/44627644
# 0
# 0
# 0
# http://destiel.pixnet.net/blog/post/17584384
# 1
# 3
# 0
# http://kwcheng0119.pixnet.net/blog/post/47337756
# 0
# 0
# 0
# http://darren2000.pixnet.net/blog/post/6118594
# 0
# 1
# 0
# http://minhuey.pixnet.net/blog/post/28783317
# 0
# 0
# 0
# http://twinklebell28.pixnet.net/blog/post/29133893
# 0
# 0
# 0
# http://ljhuang.pixnet.net/blog/post/15311726
# 0
# 0
# 0
# http://ljhuang.pixnet.net/blog/post/16456611
# 0
# 0
# 0
# http://alic63.pixnet.net/blog/post/30932435
# 0
# 0
# 0
# http://austintodo.pixnet.net/blog/post/23821430
# 0
# 0
# 0
# http://changyy.pixnet.net/blog/post/22200446
# 0
# 0
# 3
# http://slinbody.pixnet.net/blog/post/9753825
# 0
# 0
# 0
# http://changyy.pixnet.net/blog/post/31609957
# 1
# 1
# 0
# http://aquatower.pixnet.net/blog/post/24923271
# 0
# 0
# 0
# http://xxab.pixnet.net/blog/post/6713140
# 0
# 0
# 0
# http://alic63.pixnet.net/blog/post/29441050
# 0
# 0
# 0
# http://himonohydepunk.pixnet.net/blog/post/194661289
# 3
# 1
# 0
# http://pentiumto.pixnet.net/blog/post/47370623
# 0
# 0
# 2
# http://happy2005ha.pixnet.net/blog/post/289057112
# 0
# 0
# 0
# http://shinhwa324ever.pixnet.net/blog/post/138598847
# 0
# 3
# 0
# http://shinhwa324ever.pixnet.net/blog/post/144064414
# 1
# 0
# 0
# http://alic63.pixnet.net/blog/post/32017567
# 0
# 0
# 0
# http://himonohydepunk.pixnet.net/blog/post/197049229
# 17
# 25
# 1
# http://shinhwa324ever.pixnet.net/blog/post/142843544
# 1
# 0
# 0
# http://fudanshi.pixnet.net/blog/post/96439190
# 2
# 1
# 0
# http://darren2000.pixnet.net/blog/post/16769406
# 0
# 0
# 0
# http://patrick001.pixnet.net/blog/post/26290616
# 0
# 0
# 0
# http://aquatower.pixnet.net/blog/post/24924024
# 0
# 0
# 0
# http://kmufc.pixnet.net/blog/post/44574331
# 0
# 0
# 0
# http://cttc2007.pixnet.net/blog/post/29153527
# 0
# 0
# 1
# http://nknuart2013.pixnet.net/blog/post/192030006-美術系系展fb粉絲專頁連結
# 0
# 0
# 0
# http://a0923797676.pixnet.net/blog/post/34344347
# 0
# 0
# 0
# http://scuimage.pixnet.net/blog/post/405262333
# 0
# 0
# 0
# http://musicart88.pixnet.net/blog/post/70788170
# 0
# 0
# 5
# http://e121302001.pixnet.net/blog/post/62507192-市政府翻新小資的家
# 0
# 0
# 0
# http://khvision.pixnet.net/blog/post/27404676
# 0
# 0
# 0
# http://sgechild.pixnet.net/blog/post/273557446
# 0
# 0
# 0
# http://by15948.pixnet.net/blog/post/30911210
# 0
# 0
# 1
# http://akila1978.pixnet.net/blog/post/156124952
# 0
# 0
# 0
# http://khvision.pixnet.net/blog/post/28813664
# 0
# 0
# 0
# http://csafz0706.pixnet.net/blog/post/356598156
# 0
# 0
# 0
# http://opcc.pixnet.net/blog/post/106688015-高雄縣旅遊景點--推薦hot【高雄縣旅遊景點】
# 1
# 1
# 1
# http://flannel19.pixnet.net/blog/post/166855320
# 0
# 0
# 1
# http://chingmom.pixnet.net/blog/post/352993205
# 2
# 0
# 1
# http://animapx.pixnet.net/blog/post/175618677
# 0
# 0
# 0
# http://kuo094212.pixnet.net/blog/post/58353663
# 0
# 0
# 1
# http://frank2820580.pixnet.net/blog/post/44703844
# 1
# 0
# 0
# http://xingan2013.pixnet.net/blog/post/336440348
# 0
# 0
# 0
# http://uniden.pixnet.net/blog/post/30498358
# 0
# 0
# 1
# http://bigbang1314.pixnet.net/blog/post/361062920
# 4
# 2
# 0
# http://monacoclub.pixnet.net/blog/post/42443575
# 2
# 1
# 0
# http://fpk10401.pixnet.net/blog/post/26733237
# 1
# 0
# 0
# http://fdsarqqq.pixnet.net/blog/post/428589320
# 1
# 0
# 2
# http://ayumi0218.pixnet.net/blog/post/406793953
# 2
# 0
# 0
# http://salupao.pixnet.net/blog/post/24300772
# 3
# 3
# 1
# http://call0937458545.pixnet.net/blog/post/41004172
# 0
# 0
# 0
# http://momosbaby.pixnet.net/blog/post/29616806
# 0
# 0
# 0
# http://inwusaint29.pixnet.net/blog/post/26344298
# 0
# 0
# 0
# http://elleryqueen.pixnet.net/blog/post/14693719
# 0
# 0
# 0
# http://icefly.pixnet.net/blog/post/22158222
# 0
# 0
# 0
# http://twiststurns.pixnet.net/blog/post/32696098
# 0
# 0
# 0
# http://linda0818.pixnet.net/blog/post/160226351
# 1
# 0
# 0
# http://yinru.pixnet.net/blog/post/2717105
# 0
# 0
# 0
# http://yi0129.pixnet.net/blog/post/22471587
# 0
# 1
# 0
# http://wow31136.pixnet.net/blog/post/28625024
# 0
# 0
# 0
# http://sophisttw.pixnet.net/blog/post/157433213
# 1
# 0
# 1
# http://aluminum.pixnet.net/blog/post/15672876
# 0
# 1
# 0
# http://secretsigns.pixnet.net/blog/post/12704311
# 1
# 0
# 1
# http://yamamiki.pixnet.net/blog/post/6929736
# 1
# 1
# 0
# http://seanwoo.pixnet.net/blog/post/40784263-box
# 0
# 1
# 0
# http://redplumes.pixnet.net/blog/post/37344924
# 0
# 0
# 1
# http://addsopq.pixnet.net/blog/post/22639580
# 1
# 0
# 0
# http://pou2100.pixnet.net/blog/post/289414570
# 0
# 1
# 0
# http://gameswu.pixnet.net/blog/post/22869792
# 0
# 0
# 0
# http://maggie98.pixnet.net/blog/post/325217427
# 0
# 0
# 0
# http://a1092177.pixnet.net/blog/post/23363911
# 0
# 0
# 0
# http://attken.pixnet.net/blog/post/92069595
# 0
# 0
# 0
