# %%
import requests
from bs4 import BeautifulSoup

res=requests.get('http://blog.xuite.net/rubyintainan/blog/498867118')
res.encoding='utf-8'
print (res.text)
soup = BeautifulSoup (res.text, "lxml")
Main_article=soup.select('.ArticleContent')
print(Main_article)
# Out:
# <script src="//s.blog.xuite.net/_public/js/BlogPlugins.leading_area.js?v=//img.xuite.net/_v_1.0.116"></script><!--[if lt IE 9]><script src="//img.xuite.net/xui/plugins/html5shiv.js" ></script><![endif]--><script language="javascript" type="text/javascript" src="//s.blog.xuite.net/_public/js/blog_01.js?v=//img.xuite.net/_v_1.0.116"></script><script language="javascript" type="text/javascript" src="//s.blog.xuite.net/_public/js/AC_RunActiveContent.js"></script><link rel="meta" href="//s.blog.xuite.net/_public/js/labels.rdf" type="application/rdf+xml" title="ICRA labels" /><title>中西區【ART BOX B.T.S】肉粽蛋餅-中正路 @  嚕比愛食台南 :: 隨意窩 Xuite日誌</title><!--hinet所提供的css:Begin --><link rel="stylesheet" type="text/css" href="//img.xuite.net/_v_1.0.116/personal/blog/fix.css" /><!--hinet所提供的css:End --><link href="//f.blog.xuite.net/_v_1492169641/f/1/2/0/237178954/blog_3352036/blog.css" rel="stylesheet" type="text/css" /><SCRIPT language="javascript" type="text/javascript" src="//s.blog.xuite.net/_public/js
# ...
