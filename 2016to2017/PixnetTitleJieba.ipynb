# %%
import requests
import MySQLdb
from bs4 import BeautifulSoup
import jieba
import jieba.analyse

def remove_values_from_list(the_list, val):
    return [value for value in the_list if value != val]

def get_web_page(url): #原始地址
    time.sleep(0.5)  # 每次爬取前暫停 0.5 秒以免被 PTT 網站判定為大量惡意爬取
    resp = requests.get(
        url=url,
        cookies={'over18': '1'}
    )
    return resp.text

jieba.set_dictionary('dict.txt.big')

conn = MySQLdb.connect(host="localhost", user="root", passwd="", db="python",charset='utf8')#連結資料庫
cur = conn.cursor()
cur.execute("SELECT search_href,id,search_title FROM pixnet")
results = cur.fetchall()

for record in results:    
    db_url = record[0]
    pixnet_id = record[1]
    title=record[2]
    title_list=jieba.lcut(title,cut_all=False)
    print(title_list)
    
    res=requests.get(db_url)
    res.encoding='utf-8'
    soup = BeautifulSoup (res.text, "html5lib")
    soup2 =  soup.select('meta')[1]

    original_url =soup2['content'].lstrip('3;url=')
    print (original_url)

    res1=requests.get('original_url')
    res1.encoding='utf-8'
    soup1 = BeautifulSoup (res1.text, "html5lib")
    #內文
    main_article = soup1.select('.article-content-inner')    

    content=main_article[0].text.strip()
    sentence=content.split("\n")
    sentence=remove_values_from_list(sentence,'')


    total_count=0
    total_article_count=0
    for line in sentence:

        line2=line.strip()
        words=jieba.lcut(line2, cut_all=False)

        s1 = set(title_list)
        s2 = set(words)
        article_count=len(s2)
        total_article_count=total_article_count+article_count
        intersection=s1.intersection(s2)
        count=len(intersection)
        total_count=total_count+count
    
    print(total_article_count)
    print(total_count)
    print(format(total_count/total_article_count,'0.1%'))
# Out:
# Building prefix dict from C:\Users\wlunareve\python\dict.txt.big ...
# Loading model from cache C:\Users\WLUNAR~1\AppData\Local\Temp\jieba.ube0c4e67d291f94013d7023df2b3161e.cache
# Loading model cost 1.382 seconds.
# Prefix dict has been built succesfully.
# ['地瓜', '麵', '包']
# http://jesiarki.pixnet.net/blog/post/45500404
# 124
# 2
# 1.6%
# ['【', '7', '-', '11', '】', '夏日', '大', '感謝', '祭', '\u3000', '麵', '包', '任選', '第', '2', '件', '5', '折']
# http://luckykitty.pixnet.net/blog/post/43674835
# 124
# 3
# 2.4%
# ['Sweet', ' ', 'Betty', '西點', '沙龍', ' ', '五分鐘', '能', '做', '完', '麵', '包', '？', '這', '怎麼', '可能', '！']
# http://jinnic51345.pixnet.net/blog/post/39205595
# 124
# 10
# 8.1%
# ['【', '厚生', '分享', '】', '荔枝', '乾', '除了', '直接', '吃', '，', '還有', '什麼', '用途', '？']
# http://farmdirect01.pixnet.net/blog/post/300730922
# 124
# 1
# 0.8%
# ['Pepperoni', ' ', 'Pizza', ' ', 'Buns', '~', 'Pizza', ' ', '麵', '包', '做法']
# http://joyceliu9146.pixnet.net/blog/post/36916206-pepperoni-pizza-buns~pizza-麵包做法
# 124
# 8
# 6.5%
# ['<', '麵', '團', '整型', '>', '辮子', '整型', '~', '變成', '可愛', '的', '麵', '包']
# http://naomi0408.pixnet.net/blog/post/202744117-<麵團整型>辮子整型~變成可愛的麵包
# 124
# 5
# 4.0%
# ['微波', '麵', '包', '(', '中種', '冷藏法', ')']
# http://na0d0005.pixnet.net/blog/post/214518998
# 124
# 6
# 4.8%
# ['奶', '香濃', '的', '酒香', '葡萄乾', '杏仁', '奶酥', '餡']
# http://ninaground.pixnet.net/blog/post/398023396-奶香濃的酒香葡萄乾杏仁奶酥餡
# 124
# 3
# 2.4%
# ['黑心', ':', '王品', '「', '曼', '咖啡', '」', '也', '染', '餿油', '下架', ' ', '山崎', '麵', '包', '「', '湯', '」', '沃克', '牛排', '「', '醬', '」', '摻', '餿', '下架']
# http://s9902273.pixnet.net/blog/post/41550485
# 124
# 9
# 7.3%
# ['紅龍', '果', '黑糖', '小饅頭']
# http://sukioooru.pixnet.net/blog/post/285989557
# 124
# 0
# 0.0%
# ['<', '麵', '團', '整型', '>', '菊花', '整型', '~', '中式', '點心', '也', '適合']
# http://naomi0408.pixnet.net/blog/post/202743502-<麵團整型>菊花麵包整型~中式點心很適合的造
# 124
# 3
# 2.4%
# ['麵', '包', '新手', 'DIY', '／', '全麥', '吐司', ' ', '-', '-', '好文', '收藏']
# http://t3design.pixnet.net/blog/post/100754539
# 124
# 9
# 7.3%
# ['去', '龍騰', '社區', '上', '麵', '包課']
# http://c31285.pixnet.net/blog/post/9917761
# 124
# 3
# 2.4%
# ['nutella', ' ', '&', '花生醬', ' ', '聖誕樹', '麵', '包']
# http://joyceliu9146.pixnet.net/blog/post/182047743-nutella-&花生醬-聖誕樹麵包
# 124
# 8
# 6.5%
# ['【', '珍珠', '糖', '比利時', '鬆餅', '】']
# http://fw41688.pixnet.net/blog/post/204891544
# 124
# 0
# 0.0%
# ['麵', '包碗', '(', '圓法', ')', '作法']
# http://joyceliu9146.pixnet.net/blog/post/36927963-麵包碗(圓法)作法
# 124
# 6
# 4.8%
# ['麵', '包', '布丁']
# http://jesiarki.pixnet.net/blog/post/50418338
# 124
# 2
# 1.6%
# ['食記', '～', '聯美', '西點', '麵', '包', '～', '飄香', '三十多年']
# http://yihui517.pixnet.net/blog/post/13478983
# 124
# 2
# 1.6%
# ['<', '麵', '團', '整型', '>', '三', '丸子', '整型']
# http://naomi0408.pixnet.net/blog/post/202744921-<麵團整型>三丸子整型
# 124
# 2
# 1.6%
# ['{', '飲料', '}', '原萃', ' ', ' ', ' ', '東方', '美人', '茶']
# http://yida200623.pixnet.net/blog/post/324601509-{飲料}原萃---東方美人茶
# 124
# 6
# 4.8%
# ['做', '麵', '包碗', '(', '圓法', ')', '來', '裝湯', '~', '~', 'New', ' ', 'England', ' ', 'Clam', ' ', 'Chowder', '(', '巧達', '蛤蠣', '濃湯', ')']
# http://joyceliu9146.pixnet.net/blog/post/93582897-做麵包碗(圓法)來裝湯~~new-england-clam-chowder(巧
# 124
# 12
# 9.7%
# ['黃', '麗星', '『', '轉眼之間', '』', '專輯', '-', '幕後', '功臣', '篇', '之', '6', '-', '謝銘', '祐']
# http://reisei888.pixnet.net/blog/post/25969571
# 124
# 1
# 0.8%
# ['楓糖', '免', '揉', '麵', '包']
# http://sevenfishes7.pixnet.net/blog/post/174875403
# 124
# 2
# 1.6%
# ['SD', '-', 'BMS105T', ' ', '佛卡夏']
# http://chioutian.pixnet.net/blog/post/398796748
# 124
# 7
# 5.6%
# ['不知', '會', '吃', '到', '那種', '餡', '的', '優格圓', '麵', '包']
# http://ninaground.pixnet.net/blog/post/395460976-不知會吃到那種餡的優格圓麵包
# 124
# 6
# 4.8%
# ['義大利', '水果', '麵', '包', ' ', '(', '2013', '年', '版本', ')']
# http://jesiarki.pixnet.net/blog/post/54470204
# 124
# 16
# 12.9%
# ['竹崎', '。', '小吃', '之旅', '。', '正達', '麵', '包', '烘培', '坊']
# http://villagevilla.pixnet.net/blog/post/38655631
# 124
# 2
# 1.6%
# ['雜糧', '麵', '包', 'v', '.', 's', '全麥', '麵', '包', '(', '新聞', '分享', ')']
# http://workhome.pixnet.net/blog/post/190288806
# 124
# 6
# 4.8%
# ['如何', '辨別', '長', '棍', '麵', '包', '好壞', '(', '新聞', '分享', ')']
# http://workhome.pixnet.net/blog/post/195058692
# 124
# 6
# 4.8%
# ['[', '烘焙', '分享', ']', '奶油', '吐司']
# http://b017292003.pixnet.net/blog/post/32434757
# 124
# 2
# 1.6%
# ['《', '老人斑', '預防', '改善', '》', '老人斑', ' ', '長期', '累積', '紫外線', '傷害', '(', '皮膚科', '/', '雷射', '美白', '/', '台', '中', '/', '曾', '石姿', '醫師', ')']
# http://ruianc.pixnet.net/blog/post/42165581
# 124
# 10
# 8.1%
# ['整理', '-', '如何', '去除', '老人', '味']
# http://beautydiy.pixnet.net/blog/post/31520388
# 124
# 1
# 0.8%
# ['台中市', '補助', '老人', '健', '保費', '\u3000', '最高', '749', '元']
# http://a643688.pixnet.net/blog/post/170194611
# 124
# 0
# 0.0%
# ['老人', '山中', '昏倒', ' ', '忠狗', '體溫', '救', '主人']
# http://apbb.pixnet.net/blog/post/41634035
# 124
# 6
# 4.8%
# ['擦', '的', '葡萄糖', '胺', '關節', '師傅', '葡萄糖', '胺', '5592', ' ', '關節炎', 'MSM', ' ', '退化', '性', '關節炎', ' ', 'http', ':', '/', '/', 'www', '.', '535559']
# http://caleb243545.pixnet.net/blog/post/215695967
# 124
# 9
# 7.3%
# ['重溫', '新婚', ' ', '台南', '老人', '免費', '拍', '婚紗']
# http://lawg.pixnet.net/blog/post/69194118
# 124
# 6
# 4.8%
# ['聖誕', '傳騎', ' ', '美麗', '台灣', '11', '/', '17']
# http://eat8185.pixnet.net/blog/post/33509729
# 124
# 6
# 4.8%
# ['聖誕', '老公公', '回信', '了', '!', '!', '!', '!', '!', '!', '!', '!', '!']
# http://annyhuang.pixnet.net/blog/post/31567621
# 124
# 6
# 4.8%
# ['Ba']
# http://mtrlk.pixnet.net/blog/post/14036212
# 124
# 0
# 0.0%
# ['Hellickson', "'", 's', ' ', 'BA', ' ', 'grades']
# http://andrenomo.pixnet.net/blog/post/26627415
# 124
# 6
# 4.8%
# ['○', ' ', 'BA']
# http://carriemore2.pixnet.net/blog/post/30159355
# 124
# 6
# 4.8%
# ['ba']
# http://kenji7777.pixnet.net/blog/post/66734933
# 124
# 0
# 0.0%
# ['癌症', '不是', '老人', '病', '!', ' ', '1', '/', '3', '可', '預防']
# http://cancer881881.pixnet.net/blog/post/115884077-癌症不是老人病!-1-3可預防
# 124
# 8
# 6.5%
# ['如何', '鼓勵', '老人家', '抗癌', '？', ' ', '耐心', '解說', '治療', '技術']
# http://cancer881881.pixnet.net/blog/post/142741148-如何鼓勵老人家抗癌？-耐心解說治療技術
# 124
# 7
# 5.6%
# ['[', '感想', '區', ']', '\u3000', '都市', '傳說', '08', '‧', '聖誕老人', ' ', '(', '2015.12', '.', '04', ')', '\u3000', '\u3000', '迴響', '恐有雷', '，', '留意', '勿', '踩']
# http://linea.pixnet.net/blog/post/31208045
# 124
# 12
# 9.7%
# ['Ba', ' ', 'ba', '..']
# http://viola1007.pixnet.net/blog/post/9927800
# 124
# 6
# 4.8%
# ['Ba', ' ', 'Ba']
# http://gold20317.pixnet.net/blog/post/20371517
# 124
# 6
# 4.8%
# ['一日', '狂洗', '熱水澡', '4', '次', '\u3000', '女', '大生', '嫩', '肌變', '「', '老人', '皮', '」']
# http://gbhtech.pixnet.net/blog/post/75412769
# 124
# 0
# 0.0%
# ['一位', '老人', '的', '九句', '話', '~', '終身', '受用', '(', '內附', '影片', ')']
# http://smz20121215.pixnet.net/blog/post/40319695
# 124
# 7
# 5.6%
# ['六', '方壺', '-', '大彬款']
# http://swt57502.pixnet.net/blog/post/305638
# 124
# 1
# 0.8%
# ['草蜢', '-', 'Ba', ' ', 'Ba', ' ', 'Ba']
# http://kissinwang.pixnet.net/blog/post/36495049
# 124
# 7
# 5.6%
# ['http', ':', '/', '/', 'tw', '.', 'news', '.', 'yahoo', '.', 'com', '/', '%', 'E4', '%', 'BA', '%', '8B', '%', 'E7', '%', '99', '%', '...']
# http://biohazard09o.pixnet.net/blog/post/36920493
# 124
# 0
# 0.0%
# ['日航', '123']
# http://c55s55.pixnet.net/blog/post/12520341
# 124
# 0
# 0.0%
# ['出自', '專業', '投機', '原理', '的', '技術', '分析', '....', '123.2', 'B', '法則']
# http://ufclark.pixnet.net/blog/post/5018665
# 124
# 4
# 3.2%
# ['【', '宅配', '│', '美食', '】', '方便', '快速', '，', '簡單', '幸福', '的', '美味', '家常菜', '。', '123', '幸福', '美食']
# http://jason123455.pixnet.net/blog/post/200123244
# 124
# 5
# 4.0%
# ['20120804', ' ', '[', '菜單', ']', ' ', '123', '義大利', '麵', ' ', '03', '-', '8663763', ' ', '/', ' ', '0985530929']
# http://ndhu.pixnet.net/blog/post/31103431
# 124
# 15
# 12.1%
# ['【', '團購', ' ', '宅配', '】', 'Best', ' ', 'of', ' ', 'Best', ' ', '123', '幸福', '美食', '。', '十分鐘', '享受', '簡單', '的', '幸福', '美味', '。', '家庭', '必備', '的', '好', '朋友', '。']
# http://amy0404.pixnet.net/blog/post/195808851
# 124
# 11
# 8.9%
# ['【', 'iOS', '／', 'Android', '】', '123', '猜猜猜', '(', '台灣版', ')', '-', '151', '~', '200', '關', '解答', '攻略']
# http://plugger.pixnet.net/blog/post/29167699
# 124
# 5
# 4.0%
# ['【', 'iOS', '／', 'Android', '】', '123', '猜猜猜', '(', '台灣版', ')', '-', '101', '~', '150', '關', '解答', '攻略']
# http://plugger.pixnet.net/blog/post/29161705
# 124
# 5
# 4.0%
# ['【', 'iOS', '／', 'Android', '】', '123', '猜猜猜', '(', '台灣版', ')', '-', '451', '~', '500', '關', '解答', '攻略']
# http://plugger.pixnet.net/blog/post/29229227
# 124
# 5
# 4.0%
# ['▌', 'APP', ' ', '▌', '123', '猜猜猜', ' ', '(', '台灣版', ')', '♥', '猜圖', '助手', '、', '台灣', '猜猜', 'fun', '攻略', '!', '!', '!', '答案', '看', '這裡']
# http://olyflychen.pixnet.net/blog/post/245154128
# 124
# 15
# 12.1%
# ['【', 'iOS', '／', 'Android', '】', '123', '猜猜猜', '(', '台灣版', ')', '-', '251', '~', '300', '關', '解答', '攻略']
# http://plugger.pixnet.net/blog/post/29184932
# 124
# 5
# 4.0%
# ['閱讀', '橋', '梁書', '(', '99.6', '.', '1', ')']
# http://hinlin.pixnet.net/blog/post/25242218
# 124
# 5
# 4.0%
# ['♥', '【', '育兒', '大小', '識', '】', '你', '的', '寶寶', '會', '說話', '了', '嗎', '。', '寶寶', '的', '語言', '學習', '與', '教養', '-', '中文', '部分', '。', '喵', '喵', '人妻', '的', '育兒', '經驗', '(', '上集', ')']
# http://flydog0527.pixnet.net/blog/post/87690287-♥【育兒大小識】你的寶寶會說話了嗎。寶寶
# 124
# 12
# 9.7%
# ['【', '123KUBO', ' ', '酷播', '】', '123kubo', ' ', '看', '電影', '、', '看', '動漫', '、', '看', '連續劇', ' ', '線上', '看', '，', '已經', '不用', '這麼', '麻煩', '了', ' ', '(', '使用']
# http://k19980720.pixnet.net/blog/post/184353448-【123kubo-酷播】123kubo-看電影、看動漫、看連
# 124
# 12
# 9.7%
# ['最後', '一戰', 'CE', ' ', '下載', ' ', '免費', ' ', '(', '親手', '打', ')', ' ', '2017', '/', '03', '/', '19', ' ', '更新', '：', '雜項', '(', '?']
# http://charlton343117tw.pixnet.net/blog/post/34441767
# 124
# 10
# 8.1%
# ['NBA', ' ', '123']
# http://time2011.pixnet.net/blog/post/95133086
# 124
# 6
# 4.8%
# ['123']
# http://rs7822.pixnet.net/blog/post/1138660
# 124
# 0
# 0.0%
# ['123']
# http://je235.pixnet.net/blog/post/4541073
# 124
# 0
# 0.0%
# ['123']
# http://joe112.pixnet.net/blog/post/7923589
# 124
# 0
# 0.0%
# ['123']
# http://alice41026.pixnet.net/blog/post/1396458
# 124
# 0
# 0.0%
# ['123']
# http://peanut16.pixnet.net/blog/post/35845
# 124
# 0
# 0.0%
# ['123']
# http://minimice.pixnet.net/blog/post/6535765
# 124
# 0
# 0.0%
# ['123']
# http://nadia1990.pixnet.net/blog/post/176157865
# 124
# 0
# 0.0%
# ['123']
# http://sunnycoconut.pixnet.net/blog/post/146645912
# 124
# 0
# 0.0%
# ['123']
# http://yatingyo.pixnet.net/blog/post/1781040
# 124
# 0
# 0.0%
# ['123']
# http://achu0125.pixnet.net/blog/post/14219820
# 124
# 0
# 0.0%
# ['123']
# http://amy201006.pixnet.net/blog/post/34429729
# 124
# 0
# 0.0%
# ['123']
# http://emma1213.pixnet.net/blog/post/22839153
# 124
# 0
# 0.0%
# ['!', '123']
# http://yj1.pixnet.net/blog/post/230900
# 124
# 2
# 1.6%
# ['123']
# http://sweetkiala.pixnet.net/blog/post/10043266
# 124
# 0
# 0.0%
# ['123']
# http://simple362store62.pixnet.net/blog/post/48368754
# 124
# 0
# 0.0%
# ['《', '老人斑', '預防', '改善', '》', '老人斑', ' ', '長期', '累積', '紫外線', '傷害', '(', '皮膚科', '/', '雷射', '美白', '/', '台', '中', '/', '曾', '石姿', '醫師', ')']
# http://ruianc.pixnet.net/blog/post/42165581
# 124
# 10
# 8.1%
# ['整理', '-', '如何', '去除', '老人', '味']
# http://beautydiy.pixnet.net/blog/post/31520388
# 124
# 1
# 0.8%
# ['台中市', '補助', '老人', '健', '保費', '\u3000', '最高', '749', '元']
# http://a643688.pixnet.net/blog/post/170194611
# 124
# 0
# 0.0%
# ['老人', '山中', '昏倒', ' ', '忠狗', '體溫', '救', '主人']
# http://apbb.pixnet.net/blog/post/41634035
# 124
# 6
# 4.8%
# ['擦', '的', '葡萄糖', '胺', '關節', '師傅', '葡萄糖', '胺', '5592', ' ', '關節炎', 'MSM', ' ', '退化', '性', '關節炎', ' ', 'http', ':', '/', '/', 'www', '.', '535559']
# http://caleb243545.pixnet.net/blog/post/215695967
# 124
# 9
# 7.3%
# ['重溫', '新婚', ' ', '台南', '老人', '免費', '拍', '婚紗']
# http://lawg.pixnet.net/blog/post/69194118
# 124
# 6
# 4.8%
# ['聖誕', '傳騎', ' ', '美麗', '台灣', '11', '/', '17']
# http://eat8185.pixnet.net/blog/post/33509729
# 124
# 6
# 4.8%
# ['聖誕', '老公公', '回信', '了', '!', '!', '!', '!', '!', '!', '!', '!', '!']
# http://annyhuang.pixnet.net/blog/post/31567621
# 124
# 6
# 4.8%
# ['Ba']
# http://mtrlk.pixnet.net/blog/post/14036212
# 124
# 0
# 0.0%
# ['Hellickson', "'", 's', ' ', 'BA', ' ', 'grades']
# http://andrenomo.pixnet.net/blog/post/26627415
# 124
# 6
# 4.8%
# ['○', ' ', 'BA']
# http://carriemore2.pixnet.net/blog/post/30159355
# 124
# 6
# 4.8%
# ['ba']
# http://kenji7777.pixnet.net/blog/post/66734933
# 124
# 0
# 0.0%
# ['癌症', '不是', '老人', '病', '!', ' ', '1', '/', '3', '可', '預防']
# http://cancer881881.pixnet.net/blog/post/115884077-癌症不是老人病!-1-3可預防
# 124
# 8
# 6.5%
# ['如何', '鼓勵', '老人家', '抗癌', '？', ' ', '耐心', '解說', '治療', '技術']
# http://cancer881881.pixnet.net/blog/post/142741148-如何鼓勵老人家抗癌？-耐心解說治療技術
# 124
# 7
# 5.6%
# ['[', '感想', '區', ']', '\u3000', '都市', '傳說', '08', '‧', '聖誕老人', ' ', '(', '2015.12', '.', '04', ')', '\u3000', '\u3000', '迴響', '恐有雷', '，', '留意', '勿', '踩']
# http://linea.pixnet.net/blog/post/31208045
# 124
# 12
# 9.7%
# ['Ba', ' ', 'ba', '..']
# http://viola1007.pixnet.net/blog/post/9927800
# 124
# 6
# 4.8%
# ['Ba', ' ', 'Ba']
# http://gold20317.pixnet.net/blog/post/20371517
# 124
# 6
# 4.8%
# ['一日', '狂洗', '熱水澡', '4', '次', '\u3000', '女', '大生', '嫩', '肌變', '「', '老人', '皮', '」']
# http://gbhtech.pixnet.net/blog/post/75412769
# 124
# 0
# 0.0%
# ['一位', '老人', '的', '九句', '話', '~', '終身', '受用', '(', '內附', '影片', ')']
# http://smz20121215.pixnet.net/blog/post/40319695
# 124
# 7
# 5.6%
# ['六', '方壺', '-', '大彬款']
# http://swt57502.pixnet.net/blog/post/305638
# 124
# 1
# 0.8%
# ['草蜢', '-', 'Ba', ' ', 'Ba', ' ', 'Ba']
# http://kissinwang.pixnet.net/blog/post/36495049
# 124
# 7
# 5.6%
# ['http', ':', '/', '/', 'tw', '.', 'news', '.', 'yahoo', '.', 'com', '/', '%', 'E4', '%', 'BA', '%', '8B', '%', 'E7', '%', '99', '%', '...']
# http://biohazard09o.pixnet.net/blog/post/36920493
# 124
# 0
# 0.0%
# ['150611', '(', '桃園', ')', '可口可樂', '博物館', '@', '可樂', '限時', '喝到', '飽', '，', '呷', '免驚', 'ㄟ']
# http://hero3507.pixnet.net/blog/post/200263497
# 124
# 4
# 3.2%
# ['美國', '股票', '個股', '介紹', '-', '-', '可口可樂']
# http://ao3ej3.pixnet.net/blog/post/5817550
# 124
# 3
# 2.4%
# ['夢', '時代', '8F', '~', '~', '勝屋']
# http://yahsing1017.pixnet.net/blog/post/2606279
# 124
# 0
# 0.0%
# ['Rolleiflex', ' ', '2.8', 'F', '試拍']
# http://cy139.pixnet.net/blog/post/35176677
# 124
# 6
# 4.8%
# ['野溪', '油畫', '(', '8F', ')']
# http://jyuanhuang.pixnet.net/blog/post/221974712
# 124
# 4
# 3.2%
# ['中壢', 'Sogo', '餐廳', ' ', '8F']
# http://richpaul168.pixnet.net/blog/post/5301112
# 124
# 7
# 5.6%
# ['Interview', ' ', '-', ' ', 'Focus', ' ', '8F', ' ', ' ', 'soho']
# http://ellecju.pixnet.net/blog/post/22076930
# 124
# 7
# 5.6%
# ['油畫', ' ', '錦鯉', ' ', '8F', ' ']
# http://leoliu1014.pixnet.net/blog/post/223054562
# 124
# 6
# 4.8%
# ['8F', ' ', 'Laboratory', '服飾']
# http://rimiaaa.pixnet.net/blog/post/12678857
# 124
# 6
# 4.8%
# ['煙波', '行館', '8F']
# http://fun7life.pixnet.net/blog/post/11817382
# 124
# 0
# 0.0%
# ['尋寶', '，', 'EE', '、', '8F', '。']
# http://fox9999.pixnet.net/blog/post/8691788
# 124
# 0
# 0.0%
# ['饗家', '2017', '年', '菜', '（', '下載', '表格', 'https', ':', '/', '/', 'www', '.', 'dropbox', '.', 'com', '/', 's', '/', '835g1emzrjo']
# http://dio5680.pixnet.net/blog/post/43437290-饗家2017年菜（下載表格http:--doora.qiniudn.com-pwog
# 124
# 2
# 1.6%
# ['Rolleiflex', ' ', '2.8', 'F', '-', 'NO', '.', '1']
# http://kennycorn.pixnet.net/blog/post/202183117
# 124
# 7
# 5.6%
# ['京', '幸福', '3', '房車', '8F', ' ']
# http://caf708t.pixnet.net/blog/post/32013961
# 124
# 6
# 4.8%
# ['【', 'SIGMA', ' ', '18', '-', '50', ' ', '2.8', 'F', '】']
# http://t03ao04.pixnet.net/blog/post/25833437
# 124
# 7
# 5.6%
# ['8F', ' ', '新古典主義']
# http://nantes.pixnet.net/blog/post/8881346
# 124
# 6
# 4.8%
# ['湖畔', ' ', '8F', ' ', '壓克力', '畫']
# http://leoliu1014.pixnet.net/blog/post/223066046
# 124
# 6
# 4.8%
# ['Tru', ' ', 'Calling', ' ', 'S1', ' ', 'E5', '&', 'E6', ' ', '劇透']
# http://bandfshipper.pixnet.net/blog/post/281015
# 124
# 6
# 4.8%
# ['日航', '123']
# http://c55s55.pixnet.net/blog/post/12520341
# 124
# 0
# 0.0%
# ['出自', '專業', '投機', '原理', '的', '技術', '分析', '....', '123.2', 'B', '法則']
# http://ufclark.pixnet.net/blog/post/5018665
# 124
# 4
# 3.2%
# ['【', '宅配', '│', '美食', '】', '方便', '快速', '，', '簡單', '幸福', '的', '美味', '家常菜', '。', '123', '幸福', '美食']
# http://jason123455.pixnet.net/blog/post/200123244
# 124
# 5
# 4.0%
# ['20120804', ' ', '[', '菜單', ']', ' ', '123', '義大利', '麵', ' ', '03', '-', '8663763', ' ', '/', ' ', '0985530929']
# http://ndhu.pixnet.net/blog/post/31103431
# 124
# 15
# 12.1%
# ['【', '團購', ' ', '宅配', '】', 'Best', ' ', 'of', ' ', 'Best', ' ', '123', '幸福', '美食', '。', '十分鐘', '享受', '簡單', '的', '幸福', '美味', '。', '家庭', '必備', '的', '好', '朋友', '。']
# http://amy0404.pixnet.net/blog/post/195808851
# 124
# 11
# 8.9%
# ['【', 'iOS', '／', 'Android', '】', '123', '猜猜猜', '(', '台灣版', ')', '-', '151', '~', '200', '關', '解答', '攻略']
# http://plugger.pixnet.net/blog/post/29167699
# 124
# 5
# 4.0%
# ['【', 'iOS', '／', 'Android', '】', '123', '猜猜猜', '(', '台灣版', ')', '-', '101', '~', '150', '關', '解答', '攻略']
# http://plugger.pixnet.net/blog/post/29161705
# 124
# 5
# 4.0%
# ['【', 'iOS', '／', 'Android', '】', '123', '猜猜猜', '(', '台灣版', ')', '-', '451', '~', '500', '關', '解答', '攻略']
# http://plugger.pixnet.net/blog/post/29229227
# 124
# 5
# 4.0%
# ['▌', 'APP', ' ', '▌', '123', '猜猜猜', ' ', '(', '台灣版', ')', '♥', '猜圖', '助手', '、', '台灣', '猜猜', 'fun', '攻略', '!', '!', '!', '答案', '看', '這裡']
# http://olyflychen.pixnet.net/blog/post/245154128
# 124
# 15
# 12.1%
# ['【', 'iOS', '／', 'Android', '】', '123', '猜猜猜', '(', '台灣版', ')', '-', '251', '~', '300', '關', '解答', '攻略']
# http://plugger.pixnet.net/blog/post/29184932
# 124
# 5
# 4.0%
# ['閱讀', '橋', '梁書', '(', '99.6', '.', '1', ')']
# http://hinlin.pixnet.net/blog/post/25242218
# 124
# 5
# 4.0%
# ['♥', '【', '育兒', '大小', '識', '】', '你', '的', '寶寶', '會', '說話', '了', '嗎', '。', '寶寶', '的', '語言', '學習', '與', '教養', '-', '中文', '部分', '。', '喵', '喵', '人妻', '的', '育兒', '經驗', '(', '上集', ')']
# http://flydog0527.pixnet.net/blog/post/87690287-♥【育兒大小識】你的寶寶會說話了嗎。寶寶
# 124
# 12
# 9.7%
# ['【', '123KUBO', ' ', '酷播', '】', '123kubo', ' ', '看', '電影', '、', '看', '動漫', '、', '看', '連續劇', ' ', '線上', '看', '，', '已經', '不用', '這麼', '麻煩', '了', ' ', '(', '使用']
# http://k19980720.pixnet.net/blog/post/184353448-【123kubo-酷播】123kubo-看電影、看動漫、看連
# 124
# 12
# 9.7%
# ['最後', '一戰', 'CE', ' ', '下載', ' ', '免費', ' ', '(', '親手', '打', ')', ' ', '2017', '/', '03', '/', '19', ' ', '更新', '：', '雜項', '(', '?']
# http://charlton343117tw.pixnet.net/blog/post/34441767
# 124
# 10
# 8.1%
# ['NBA', ' ', '123']
# http://time2011.pixnet.net/blog/post/95133086
# 124
# 6
# 4.8%
# ['123']
# http://rs7822.pixnet.net/blog/post/1138660
# 124
# 0
# 0.0%
# ['123']
# http://je235.pixnet.net/blog/post/4541073
# 124
# 0
# 0.0%
# ['123']
# http://joe112.pixnet.net/blog/post/7923589
# 124
# 0
# 0.0%
# ['123']
# http://alice41026.pixnet.net/blog/post/1396458
# 124
# 0
# 0.0%
# ['123']
# http://peanut16.pixnet.net/blog/post/35845
# 124
# 0
# 0.0%
# ['123']
# http://minimice.pixnet.net/blog/post/6535765
# 124
# 0
# 0.0%
# ['123']
# http://nadia1990.pixnet.net/blog/post/176157865
# 124
# 0
# 0.0%
# ['123']
# http://sunnycoconut.pixnet.net/blog/post/146645912
# 124
# 0
# 0.0%
# ['123']
# http://yatingyo.pixnet.net/blog/post/1781040
# 124
# 0
# 0.0%
# ['123']
# http://achu0125.pixnet.net/blog/post/14219820
# 124
# 0
# 0.0%
# ['123']
# http://amy201006.pixnet.net/blog/post/34429729
# 124
# 0
# 0.0%
# ['123']
# http://emma1213.pixnet.net/blog/post/22839153
# 124
# 0
# 0.0%
# ['!', '123']
# http://yj1.pixnet.net/blog/post/230900
# 124
# 2
# 1.6%
# ['123']
# http://sweetkiala.pixnet.net/blog/post/10043266
# 124
# 0
# 0.0%
# ['123']
# http://simple362store62.pixnet.net/blog/post/48368754
# 124
# 0
# 0.0%
# ['是', '這樣', '嗎']
# http://bigbigtree.pixnet.net/blog/post/22275828
# 124
# 0
# 0.0%
# ['華茂', '地產', '網', '-', '-', '-', '-', '台灣', '-', '-', '台南市', '小', '東路', '395', '號', '0913', '-', '930', '-', '868', '不動產', '房屋買賣', '專賣店', '|', ' ', 'Fac']
# http://www0913930868.pixnet.net/blog/post/303647981
# 124
# 7
# 5.6%
# ['好吃', '熱炒', '店', '-', '-', '胖子', '小吃店', ' ']
# http://julia5168.pixnet.net/blog/post/43526806
# 124
# 8
# 6.5%
# ['Humpty', '-', 'Dumpty', ' ', 'of', ' ', 'Alice']
# http://puzzleholic.pixnet.net/blog/post/44802371
# 124
# 7
# 5.6%
# ['胖子', '小吃部', '八德', '店']
# http://ctspon.pixnet.net/blog/post/227380414-胖子小吃部八德店
# 124
# 0
# 0.0%
# ['節食', '不', '運動', '輕', '熟女', '成瘦', '胖子']
# http://changnina142.pixnet.net/blog/post/25947075-節食不運動輕熟女成瘦胖子
# 124
# 0
# 0.0%
# ['【', '台北', '比較', '姐', '】', '減肥', '陷阱', '百', '百種', ' ', '你', '最', '容易', '深陷', '哪種', '~', '(', '鞭策', '!', '!', '!', '!', '!', ')']
# http://comparelady.pixnet.net/blog/post/80431736-【台北比較姐】減肥陷阱百百種-你最容易深
# 124
# 15
# 12.1%
# ['小心', '變回', '胖子', '身', '！', '10', '招助', '瘦', '的', '聰明', '吃零食', '法']
# http://kima999999.pixnet.net/blog/post/188482827
