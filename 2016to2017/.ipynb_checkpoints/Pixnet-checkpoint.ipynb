# %%
#痞客邦PIXNET https://www.pixnet.net/
# -*- coding: UTF-8 -*-

import MySQLdb
import requests
import sys
import time
import urllib.parse
from bs4 import BeautifulSoup

conn = MySQLdb.connect(host="localhost", user="root", passwd="", db="python",charset='utf8')#連結資料庫
cur = conn.cursor()
#編碼使用
# url_key_word = sys.argv[1]
# chinese_key_word=urllib.parse.unquote(sys.argv[1])
sqli = "insert into pixnet (key_word,search_title,search_subtitle,article_picture,search_time,search_href,search_author,author_href,author_picture,search_view) values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)" #選擇資料表
chinese_key_word='MAC'
url_key_word=urllib.parse.quote('MAC')
x = 1
for  x  in range(3*x-2,3*x+1) :    
    payload={'q':url_key_word,'page':x}
    res=requests.get("https://www.pixnet.net/searcharticle",params=payload)
    res.encoding='utf-8'
    soup = BeautifulSoup (res.text, "lxml")
    for item in soup.select('.search-list'):
        
        #取出標題
        search_title = (item.select('.search-title')[0].text) 
        print(search_title)
        #取小標題
        search_subtitle=item.select('.search-desc')[0].text.strip('繼續閱讀 »') 
        
        #取出各個網址
        href =item.find('a')['href'] 
        res2=requests.get(href)
        res2.encoding='utf-8'
        soup1 = BeautifulSoup (res2.text, "lxml")
        soup2 =  soup1.select('meta')[1]
        search_href =soup2['content'].lstrip('3;url=')
        
        #取得發表時間
        search_time = item.select('.search-postTime')[0].text
        
        #文章圖片
        href_res=requests.get(search_href)
        href_res.encoding='utf-8'
        soup3 = BeautifulSoup (href_res.text, "html5lib")
        main_article = soup3.select('.article-content-inner')
        article_picture = main_article[0].find('img')['src']
        
        #作者名字
        search_author=item.select('.search-author')[0].text 
                
        #作者部落格           
        for author in item.select('.search-meta'):
            author_href=author.find('a')['href']
            

        #取出作者圖片    
        for src in item.select('.search-avatar'):
            author_picture=item.find('img')['src']
           
        #文章人氣
        search_view= item.select('.search-views')[0].text.strip('人氣( )')

        time.sleep(0.5)

        cur.execute(sqli,(chinese_key_word,search_title, search_subtitle, article_picture, search_time, search_href, search_author, author_href, author_picture,search_view)) #存入資料庫    
        conn.commit()

cur.close() #斷開連結
conn.close()
# Out:
# http://royalyao.pixnet.net/blog/post/28243263
# http://pic.pimg.tw/royalyao/1346166268-1544239065_m.jpg
# http://snowkei.pixnet.net/blog/post/19717727
# http://pic.pimg.tw/snowkei/1215546201.jpg
# http://showmer.pixnet.net/blog/post/43199086-macx-video-converter-pro
# https://pic.pimg.tw/showmer/1450426930-3770070579_n.png?v=1450426932
# http://chunju.pixnet.net/blog/post/40993849
# http://3.blog.xuite.net/3/c/3/f/12973476/blog_65624/txt/220741404/0.jpg
# http://droger.pixnet.net/blog/post/1137771
# http://s.pimg.tw/avatar/droger/0/0/resize/80x0.png?v=1252642697
# http://pf77501.pixnet.net/blog/post/35180947
# http://pic.pimg.tw/pf77501/1313835881-0c981aab318f9cfd2a00d10e1b416e66.jpg
# http://macwei.pixnet.net/blog/post/5592442
# http://pic.pimg.tw/macwei/4ba8d0ca3ebb2.png
# http://mam11213.pixnet.net/blog/post/386308505-microsoft-office-for-mac-2011-繁體中文破解版下载
# https://pic.pimg.tw/mam11213/1432446515-593247290.jpg
# http://jimgau.pixnet.net/blog/post/24776594
# http://pic.pimg.tw/jimgau/2bbe5497693f1013d8de3065974896eb.png
# http://sinshow.pixnet.net/blog/post/21923254
# http://pic.pimg.tw/sinshow/48d2056604df3.jpg
# http://mulicia.pixnet.net/blog/post/27835285
# http://pic.pimg.tw/mulicia/1329704160-2847041999_m.jpg
# http://cpe1208.pixnet.net/blog/post/172968120
# http://d.share.photo.xuite.net/wowmis/1d1fcb7/5403771/207583036_l.jpg
# http://jimgau.pixnet.net/blog/post/23595874
# http://pic.pimg.tw/jimgau/0d23819fa420d6165a504fe401704486.png
# http://j796160836.pixnet.net/blog/post/31604715
# http://pic.pimg.tw/j796160836/1358835741-3782514491_n.png?v=1358835742
# http://goris.pixnet.net/blog/post/37739224
# http://pic.pimg.tw/goris/1364572388-210705910.jpg
# http://bluenessboy.pixnet.net/blog/post/95230816
# http://pic.pimg.tw/bluenessboy/1359464295-1256755845_l.png
# http://bob112345.pixnet.net/blog/post/108142756
# https://pic.pimg.tw/bob112345/1417773171-2058468069.jpg
# http://e10811125.pixnet.net/blog/post/102114388
# http://pic.pimg.tw/e10811125/1386684693-1245091556.jpg
# http://apple4fun.pixnet.net/blog/post/61689111
# http://pic.pimg.tw/apple4fun/5dd34b0100ee3f6f41c676e290bce498_n.png
# http://ken3ken.pixnet.net/blog/post/25381735
# http://pic.pimg.tw/ken3ken/1386200328-776484769_n.jpg
# http://kuraudocat.pixnet.net/blog/post/58990144
# http://pic.pimg.tw/kuraudocat/1389970542-904222618.jpg
# http://drmoremore.pixnet.net/blog/post/189158106-apple｜macbook-pro-retina-、new-macbook-12
# http://pic.pimg.tw/drmoremore/1414574285-1812433530_n.jpg
# http://joni.pixnet.net/blog/post/405647
# http://s3.pimg.tw/avatar/joni/0/0/resize/80x0.png?v=1279252291
# http://zn1680.pixnet.net/blog/post/18730554
# http://s1.pimg.tw/avatar/zn1680/0/0/resize/80x0.png?v=1274629420
# http://privee21.pixnet.net/blog/post/27649958
# http://pic.pimg.tw/privee21/4a02ce1ab56aa.jpg
# http://endlessartofrain.pixnet.net/blog/post/10432247
# http://s4.pimg.tw/avatar/endlessartofrain/0/0/resize/80x0.png?v=1252642324
# http://whatupvr6.pixnet.net/blog/post/4586524
# http://s3.pimg.tw/avatar/whatupvr6/0/0/resize/80x0.png?v=1265518684
# http://origin2.pixnet.net/blog/post/1126664
# http://s7.pimg.tw/avatar/origin2/0/0/resize/80x0.png?v=1252644146
# http://maviswang.pixnet.net/blog/post/1548762
# http://s4.pimg.tw/avatar/maviswang/0/0/resize/80x0.png?v=1445156335
# http://newleolion.pixnet.net/blog/post/10905740
# http://s4.pimg.tw/avatar/newleolion/0/0/resize/80x0.png?v=1252645292
