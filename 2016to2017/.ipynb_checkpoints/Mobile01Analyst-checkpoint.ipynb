# %%
import jieba
import MySQLdb
import requests
import time
from bs4 import BeautifulSoup
from selenium import webdriver

def remove_values_from_list(the_list, val):
    return [value for value in the_list if value != val]

jieba.set_dictionary('dict.txt.big')
jieba.load_userdict('userdict.txt')

conn = MySQLdb.connect(host="localhost", user="root", passwd="", db="python",charset='utf8')#連結資料庫
cur = conn.cursor() 
cur.execute("SELECT search_href,id FROM mobile01") 
            #WHERE content_analyst='-1'")
results = cur.fetchall()


# with open('positive.txt', 'r',encoding='UTF-8') as positive:
#     pos=[]
#     for line in positive:
#         pos.append(line.strip('\ufeff').strip())
#     positive.close()

# with open('nagative.txt', 'r',encoding='UTF-8') as nagative:
#     nag=[]
#     for line in nagative:
#         nag.append(line.strip('\ufeff').strip())
#     nagative.close()

# with open('paid news.txt', 'r',encoding='UTF-8') as paidnews:
#     paid=[]
#     for line in paidnews:
#         paid.append(line.strip('\ufeff').strip())
#     paidnews.close()
    
# print(pos)
# print(nag)
# print(paid)

# for record in results: 
#     db_url = record[0]
#     mobile01_id= record[1]
db_url='https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D602%26t%3D4523311&sa=U&ved=0ahUKEwitmL7u993TAhXMvrwKHWKHBo0QFggTMAA&usg=AFQjCNGwsul2EkNQEueslMYbtPClAQaLxA'
print (db_url)
    
res=requests.get(db_url)
res.encoding='utf-8'
soup = BeautifulSoup (res.text, "html5lib")
main_article=soup.select('.single-post-content')
content=main_article[0].text.strip()
sentence=content.split("\n")
sentence=remove_values_from_list(sentence,'')

total_pos_count=0
total_nag_count=0
total_paid_count=0
for line in sentence:

    line2=line.strip()
    words=jieba.lcut(line2, cut_all=False)
    words_set = set(words)
    pos_intersection=words_set.intersection(pos_set)
    nag_intersection=words_set.intersection(nag_set)
    paid_intersection=words_set.intersection(paid_set)
    pos_count=len(pos_intersection)
    nag_count=len(nag_intersection)
    paid_count=len(paid_intersection)

    total_pos_count=total_pos_count+pos_count
    total_nag_count=total_nag_count+nag_count
    total_paid_count=total_paid_count+paid_count
total_count = total_pos_count+total_nag_count+total_paid_count


if total_count==0:
    Content_Analyst = "0"

else:
    Content_Analyst = format(total_pos_count/total_count*100 , '0.2f')

cur.execute ("UPDATE pixnet SET content_analyst=%s WHERE id='%s'" %  (Content_Analyst,mobile01_id))
conn.commit()
    
cur.close() #斷開連結
conn.close()
# Out:
# Building prefix dict from C:\Users\wlunareve\python\dict.txt.big ...
# Loading model from cache C:\Users\WLUNAR~1\AppData\Local\Temp\jieba.ube0c4e67d291f94013d7023df2b3161e.cache
# Loading model cost 1.383 seconds.
# Prefix dict has been built succesfully.
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D602%26t%3D4523311&sa=U&ved=0ahUKEwitmL7u993TAhXMvrwKHWKHBo0QFggTMAA&usg=AFQjCNGwsul2EkNQEueslMYbtPClAQaLxA
# 本來沒想做這道龍蝦咖哩，因為實在太貴了
# 直到最近食戟動畫剛好播到秋選預賽的咖哩，於是就拿漫畫來複習一下
# 裡面的咖哩除了幾樣找不到材料的，就只剩下龍蝦咖哩
# 這道龍蝦咖哩實在讓人非常無語，根本是用錢砸出來的，堪稱咖哩界的金閃閃
# 主要食材就如王財的武器，全是寶具
# 主角龍蝦
# 龍蝦一定要到魚市場買，大賣場賣的不是無頭的就是波士頓龍蝦，同樣是波士頓龍蝦魚市場的就是比較大隻(不知為啥魚市場也是以波士頓龍蝦為大宗，不知道是不是比較好養)
# 排在我前面的阿伯好霸氣，挑了一隻又大又漂亮的，我只能挑一隻小的
# 水槽中的龍蝦小隻的全都傷腳斷鬚，似乎在跟你訴說弱肉強食的道理，好不容易找到一隻無傷的
# 番紅花，1公克要$419，是的，你沒看錯1公克$419，已經是一天的飯錢了
# 科涅克酒就是干邑白蘭地，等級較高的有Napoleon， X.O， Extra，對酒不是很懂
# 飲酒過量 有礙健康
# 飲酒過量 有礙健康
# 黑木場所說的拿破崙級，看圖的瓶身應該是LOUIS XIII
# 飲酒過量 有礙健康
# 飲酒過量 有礙健康
# 用不了LOUIS XIII的，選用X.O的干邑白蘭地(各位可google一下價錢)
# 黑木場本是北歐小餐館的廚師，後來遇到了愛麗絲大小姐，憑此升職加薪，雖然還是學生，卻可使用LOUIS XIII的干邑白蘭地入菜
# 此等土豪行為只能用一句話來形容
# 有錢，任性
# 這回屁話多了點，也該進入烹飪程序了
# 將龍蝦用水煮熟，取出蝦肉，蝦殼繼續放回鍋中熬成高湯
# 將熱高湯加入番紅花先溶出番紅花特殊的香味，鍋中加入白米，高湯、2大匙干邑白蘭地燉煮。
# 平底鍋中放入小茴香，洋蔥拌炒
# 洋蔥轉褐後，加入薑泥，大蒜泥，番茄碎，再拌入[芫荽+薑黃+辣椒粉]
# 拌入[辣醬油+鮮奶油+香菜碎末+番茄泥]
# 黃金色澤的番紅花飯
# 番紅花飯淋上咖哩醬汁，擺上龍蝦肉和龍蝦頭，土豪金的龍蝦咖哩就完成了
# 好吃嗎?
# 當然好吃了，這麼貴的咖哩怎麼會不好吃，誰敢說不好吃，我幹死那個王八蛋
# 番紅花飯散發清爽的香氣，新鮮的龍蝦肉粉彈牙，咖哩很香濃
# 最好吃的吃法是滴幾滴生命之水(干邑白蘭地)到蝦腦，吸一口後和番紅花飯一起吃進嘴裡
# 白蘭地的香氣混著蝦腦的鮮味，配飯吃各自的味道都能清楚的嚐到
# 美味程度可以用下面這首歌來形容
# 按這裡檢視外部影片 (按這裡在新視窗中開啟影片)
# 螢幕前的看官們，戴起耳機，音量開到最大，一起進入食戟的世界吧
# Oh，Ya~~誘~誘~誘惑的咖哩~
