# %%
#encoding=utf-8 
import jieba
import jieba.analyse
import MySQLdb
import requests
import time
from bs4 import BeautifulSoup
from selenium import webdriver

def remove_values_from_list(the_list, val):
    return [value for value in the_list if value != val]

def get_web_page(url): #原始地址
    time.sleep(0.5)  # 每次爬取前暫停 0.5 秒以免被 PTT 網站判定為大量惡意爬取
    resp = requests.get(
        url=url,
        cookies={'over18': '1'}
    )
    return resp.text

jieba.set_dictionary('dict.txt.big')

conn = MySQLdb.connect(host="localhost", user="root", passwd="", db="python",charset='utf8')#連結資料庫
cur = conn.cursor()
cur.execute("SELECT search_href,id,search_title FROM ptt")
results = cur.fetchall()


    


# 迴圈撈取資料

for record in results: 
    url = record[0]
    ptt_id = record[1]
    title=record[2]
    title_list=jieba.lcut(title,cut_all=False)
    
    print(title_list)
    print (url)
    soup=BeautifulSoup(get_web_page(url), "lxml")

    article = soup.select('div[id="main-container"]')
    #內文 
    if article!=[]:
        
        main_article=article[0].text.split("※ 發信站: 批踢踢實業坊(ptt.cc)")
        content=main_article[0].strip()
        sentence=content.split("\n")
        sentence=remove_values_from_list(sentence,'')
        title_count=len(title_list)
        total_count=0
        total_article_count=0
        for line in sentence:
            words=jieba.lcut(line, cut_all=False)
            s1 = set(title_list)
            s2 = set(words)
            article_count=len(s2)
            total_article_count=total_article_count+article_count
            intersection=s1.intersection(s2)
            count=len(intersection)
            total_count=total_count+count
            total_count=total_count-title_count
        print(total_article_count)
        print(total_count)
# Out:
# Building prefix dict from C:\Users\wlunareve\python\dict.txt.big ...
# Loading model from cache C:\Users\WLUNAR~1\AppData\Local\Temp\jieba.ube0c4e67d291f94013d7023df2b3161e.cache
# Loading model cost 1.384 seconds.
# Prefix dict has been built succesfully.
# ['[', '新聞', ']', ' ', '拍扁', '麵', '包師', '的', '麵', '包長', '這樣', '\u3000', '網友', '看', '完', '崩潰', '了']
# https://www.ptt.cc/bbs/Gossiping/M.1487646506.A.97B.html
# 34
# ['Re', ':', ' ', '[', '新聞', ']', ' ', '拍扁', '麵', '包師', '黃士', '福', '又', '出聲', '證實', '白狼', '援助', '30', '萬']
# https://www.ptt.cc/bbs/Gossiping/M.1487604802.A.B40.html
# 79
# ['[', '爆卦', ']', ' ', '記者', '看', '過來', '，', '檢舉', '麵', '包師', '的', '權貴', '在', '此', '!', '!', '!', '!']
# https://www.ptt.cc/bbs/Gossiping/M.1477991370.A.866.html
# 120
# ['[', '新聞', ']', ' ', '拍扁', '散步', '麵', '包', '師傅', '被', '肉', '搜', '\u3000', '向', '黃智賢', '求救']
# https://www.ptt.cc/bbs/Gossiping/M.1477751366.A.F66.html
# ['[', '大哭', ']', ' ', '麵', '包', '超人', '手機', '殼']
# https://www.ptt.cc/bbs/StupidClown/M.1484580448.A.96A.html
# 3
# ['[', '大哭', ']', ' ', ' ', '我', '以', '為', '我', '做', '的', '是', '麵', '包']
# https://www.ptt.cc/bbs/StupidClown/M.1490691179.A.25E.html
# 20
# ['[', '商品', ']', ' ', '統一', '克林姆', '麵', '包']
# https://www.ptt.cc/bbs/CVS/M.1471955214.A.E91.html
# 20
# ['[', '猜謎', ']', ' ', '麵', '包', '超人', '加一']
# https://www.ptt.cc/bbs/joke/M.1483973548.A.A39.html
# 1
# ['[', '閒聊', ']', ' ', '蛋黃', '哥烤', '麵', '包機']
# https://www.ptt.cc/bbs/WomenTalk/M.1467940807.A.B00.html
# 14
# ['[', '笑話', ']', ' ', '公園', '下棋', '的', '老人']
# https://www.ptt.cc/bbs/joke/M.1492866852.A.BBD.html
# 9
# ['[', 'Ｘ', 'Ｄ', ']', ' ', '有沒有', '公園', '老人', '不', '跳', '土風舞', '了', '的', '八卦', '？']
# https://www.ptt.cc/bbs/joke/M.1487673569.A.432.html
# 24
# ['[', '問卦', ']', ' ', '老人', '真的', '很', '難搞']
# https://www.ptt.cc/bbs/Gossiping/M.1481035346.A.B28.html
# 14
# ['[', '心得', ']', ' ', '下流', '老人', ' ', '讀後感', '言']
# https://www.ptt.cc/bbs/book/M.1483451311.A.472.html
# 59
# ['[', '新聞', ']', '《', '下流', '老人', '》', '作者', ':', ' ', '逼窮', '年輕人', ' ', '老人', '將遭棄']
# https://www.ptt.cc/bbs/PublicIssue/M.1479973888.A.967.html
# 66
# ['聖誕', '短篇', '：', '聖誕老人']
# https://www.ptt.cc/bbs/marvel/M.1482577141.A.059.html
# 33
# ['[', '笑話', ']', '夜校', '老人', '集體', '作弊']
# https://www.ptt.cc/bbs/joke/M.1464927065.A.082.html
# 4
# ['Re', ':', ' ', '[', '閒聊', ']', ' ', '帶', '老人', '自由', '行', '的', '感想']
# https://www.ptt.cc/bbs/Japan_Travel/M.1456681488.A.BB5.html
# 123
# ['[', '新聞', ']', ' ', '1', '／', '3', '退休', '公務員', ' ', '將成', '下流', '老人']
# https://www.ptt.cc/bbs/Gossiping/M.1486263927.A.E04.html
# 28
# ['[', '問題', ']', ' ', '123', '？']
# https://www.ptt.cc/bbs/LoL/M.1408113575.A.97C.html
# 7
# ['[', '情報', ']', ' ', '新北', '三重', ' ', '新北', '三重', ' ', '123', '清粥', '小菜', ' ', '100', '吃', '到', '飽']
# https://www.ptt.cc/bbs/EatToDie/M.1488141989.A.C73.html
# 36
# ['[', '實況', ']', ' ', 'FW', ' ', 'tom60229']
# https://www.ptt.cc/bbs/Hearthstone/M.1479623272.A.785.html
# 4
# ['[', '閒聊', ']', ' ', '123']
# https://www.ptt.cc/bbs/WomenTalk/M.1471076229.A.997.html
# 2
# ['[', '猜謎', ']', ' ', '123']
# https://www.ptt.cc/bbs/joke/M.1455264487.A.F6B.html
# 0
# ['[', '耍', '冷', ']', ' ', '123', ' ', ' ', ' ']
# https://www.ptt.cc/bbs/joke/M.1420636360.A.56C.html
# 4
# ['[', '閒聊', ']', ' ', '我', '的', '英雄', '學院', ' ', '123', ' ', '熟肉', '觀後', '心得']
# https://www.ptt.cc/bbs/C_Chat/M.1485147770.A.9B9.html
# 24
# ['[', '問題', ']', ' ', '123']
# https://www.ptt.cc/bbs/B013021XX/M.1432470059.A.D48.html
# 1
# ['[', '抱怨', ']', ' ', '123', '團購網', '消費', '經驗']
# https://www.ptt.cc/bbs/e-shopping/M.1377077804.A.68E.html
# 73
# ['[', '笑話', ']', ' ', '公園', '下棋', '的', '老人']
# https://www.ptt.cc/bbs/joke/M.1492866852.A.BBD.html
# 9
# ['[', 'Ｘ', 'Ｄ', ']', ' ', '有沒有', '公園', '老人', '不', '跳', '土風舞', '了', '的', '八卦', '？']
# https://www.ptt.cc/bbs/joke/M.1487673569.A.432.html
# 24
# ['[', '問卦', ']', ' ', '老人', '真的', '很', '難搞']
# https://www.ptt.cc/bbs/Gossiping/M.1481035346.A.B28.html
# 14
# ['[', '心得', ']', ' ', '下流', '老人', ' ', '讀後感', '言']
# https://www.ptt.cc/bbs/book/M.1483451311.A.472.html
# 59
# ['[', '新聞', ']', '《', '下流', '老人', '》', '作者', ':', ' ', '逼窮', '年輕人', ' ', '老人', '將遭棄']
# https://www.ptt.cc/bbs/PublicIssue/M.1479973888.A.967.html
# 66
# ['聖誕', '短篇', '：', '聖誕老人']
# https://www.ptt.cc/bbs/marvel/M.1482577141.A.059.html
# 33
# ['[', '笑話', ']', '夜校', '老人', '集體', '作弊']
# https://www.ptt.cc/bbs/joke/M.1464927065.A.082.html
# 4
# ['Re', ':', ' ', '[', '閒聊', ']', ' ', '帶', '老人', '自由', '行', '的', '感想']
# https://www.ptt.cc/bbs/Japan_Travel/M.1456681488.A.BB5.html
# 123
# ['[', '新聞', ']', ' ', '1', '／', '3', '退休', '公務員', ' ', '將成', '下流', '老人']
# https://www.ptt.cc/bbs/Gossiping/M.1486263927.A.E04.html
# 28
# ['[', '商品', ']', ' ', '711', ' ', '可口可樂', '汽水', '橘子', '口味']
# https://www.ptt.cc/bbs/CVS/M.1493042780.A.910.html
# 17
# ['[', '情報', ']', ' ', '《', '進擊', '的', '巨人', '》', '登', '可口可樂', ' ', '台灣', '限量', '推出']
# https://www.ptt.cc/bbs/Isayama/M.1491996238.A.B48.html
# 66
# ['Re', ':', ' ', '[', '情報', ']', ' ', '《', '進擊', '的', '巨人', '》', '登', '可口可樂', ' ', '台灣', '限量', '推出']
# https://www.ptt.cc/bbs/Isayama/M.1492806481.A.207.html
# 111
# ['[', '商品', ']', ' ', '可口可樂', '檸檬', '口味']
# https://www.ptt.cc/bbs/CVS/M.1461325310.A.F47.html
# 9
# ['[', '商品', ']', ' ', '可口可樂', '新品', ':', 'COCACOLA', ' ', 'LIFE']
# https://www.ptt.cc/bbs/CVS/M.1440076278.A.573.html
# 16
# ['[', '問題', ']', ' ', '7', '-', '11', ' ', '可口可樂', '冰沙', '機器', '?']
# https://www.ptt.cc/bbs/CVS/M.1483017417.A.233.html
# 6
# ['Fw', ':', ' ', '[', '新聞', ']', '《', '進擊', '的', '巨人', '》', '登', '可口可樂', ' ', '台灣', '限量', '推出', '「']
# https://www.ptt.cc/bbs/C_Chat/M.1491996233.A.142.html
# 108
# ['[', '請益', ']', ' ', '可口可樂', ' ', '商化', '人員']
# https://www.ptt.cc/bbs/Salary/M.1406372652.A.24B.html
# 0
# ['[', '公司', ']', ' ', '台灣', '太古', '可口可樂', '儲備', '幹部']
# https://www.ptt.cc/bbs/Salary/M.1431973846.A.D15.html
# 46
# ['[', '問題', ']', ' ', '請教', '有', '面試', '過', '可口可樂', '的', '朋友']
# https://www.ptt.cc/bbs/Salary/M.1459943480.A.E7F.html
# 21
# ['[', '問題', ']', ' ', '123', '？']
# https://www.ptt.cc/bbs/LoL/M.1408113575.A.97C.html
# 7
# ['[', '情報', ']', ' ', '新北', '三重', ' ', '新北', '三重', ' ', '123', '清粥', '小菜', ' ', '100', '吃', '到', '飽']
# https://www.ptt.cc/bbs/EatToDie/M.1488141989.A.C73.html
# 36
# ['[', '猜謎', ']', ' ', '123']
# https://www.ptt.cc/bbs/joke/M.1455264487.A.F6B.html
# 0
# ['[', '閒聊', ']', ' ', '我', '的', '英雄', '學院', ' ', '123', ' ', '熟肉', '觀後', '心得']
# https://www.ptt.cc/bbs/C_Chat/M.1485147770.A.9B9.html
# 24
# ['[', '閒聊', ']', ' ', '123']
# https://www.ptt.cc/bbs/WomenTalk/M.1471076229.A.997.html
# 2
# ['[', '耍', '冷', ']', ' ', '123', ' ', ' ', ' ']
# https://www.ptt.cc/bbs/joke/M.1420636360.A.56C.html
# 4
# ['[', '請問', ']', ' ', '一個團', '康', '遊戲', '(', '123', ')']
# https://www.ptt.cc/bbs/ask/M.1406112225.A.794.html
# 3
# ['[', '抱怨', ']', ' ', '123', '團購網', '消費', '經驗']
# https://www.ptt.cc/bbs/e-shopping/M.1377077804.A.68E.html
# 73
# ['Re', ':', ' ', '[', '閒聊', ']', ' ', '我', '的', '英雄', '學院', ' ', '123', ' ', '熟肉', '觀後', '心得']
# https://www.ptt.cc/bbs/C_Chat/M.1485190696.A.50D.html
# 25
# ['[', '討論', ']', ' ', '胖子', '力量', '比較', '大']
# https://www.ptt.cc/bbs/MuscleBeach/M.1459344265.A.8B5.html
# 8
# ['[', '討論', ']', ' ', 'Re', ':', ' ', '[', '討論', ']', ' ', '胖子', '力量', '比較', '大']
# https://www.ptt.cc/bbs/MuscleBeach/M.1459368091.A.AFB.html
# 13
# ['[', '心情', ']', ' ', '不會', '有人', '愛我', '的', '，', '因為', '我', '是', '個', '胖子']
# https://www.ptt.cc/bbs/Boy-Girl/M.1374593237.A.279.html
# 124
# ['[', '問題', ']', ' ', '真的', '會', '有', '女生', '喜歡', '胖', '男', '嗎']
# https://www.ptt.cc/bbs/WomenTalk/M.1475056633.A.684.html
# 9
# ['[', '閒聊', ']', ' ', '胖子', '可以', '當', '刺客', '嗎', '？']
# https://www.ptt.cc/bbs/C_Chat/M.1483076049.A.EA6.html
# 8
# ['[', '討論', ']', ' ', '胖子', '一定', '短', '屌', '嗎', '？']
# https://www.ptt.cc/bbs/sex/M.1418657107.A.7EC.html
# 9
# ['[', '笑話', ']', ' ', '胖子']
# https://www.ptt.cc/bbs/joke/M.1488895389.A.434.html
# 3
# ['Re', ':', ' ', '[', '笑話', ']', ' ', '胖子']
# https://www.ptt.cc/bbs/joke/M.1488897666.A.183.html
# 1
# ['Re', ':', ' ', '[', '笑話', ']', ' ', '胖子']
# https://www.ptt.cc/bbs/joke/M.1488901201.A.0F4.html
# 1
# ['Re', ':', ' ', '[', '情報', ']', '5', '月', '電腦', '王']
# https://www.ptt.cc/bbs/AntiVirus/M.1241922987.A.4C4.html
# 86
# ['Re', ':', ' ', '[', '情報', ']', ' ', 'sguza', '.', 'exe']
# https://www.ptt.cc/bbs/AntiVirus/M.1277280579.A.9B6.html
# 104
# ['[', '情報', ']', ' ', 'sguza', '.', 'exe']
# https://www.ptt.cc/bbs/AntiVirus/M.1276920358.A.88B.html
# 95
# ['[', '問題', ']', ' ', '什麼', '事是', '真', '高雄人', '才', '知道', '的', '？']
# https://www.ptt.cc/bbs/Kaohsiung/M.1487850521.A.A92.html
# 6
# ['[', '問卦', ']', ' ', '台中會', '不會', '差高雄', '越來越', '多', '..']
# https://www.ptt.cc/bbs/Gossiping/M.1480349933.A.0A1.html
# 0
# ['[', '閒聊', ']', ' ', '我', '做', '了', '一張', '高雄', '咖啡廳', '地圖']
# https://www.ptt.cc/bbs/Kaohsiung/M.1480728416.A.EB7.html
# 20
# ['Re', ':', ' ', '[', '閒聊', ']', ' ', '在', '高雄', '工作', '的', '大家', '薪情', '如何', '?']
# https://www.ptt.cc/bbs/Kaohsiung/M.1463110275.A.C18.html
# 124
# ['Re', ':', ' ', '[', '請益', ']', ' ', '高雄', '有', '哪些', '值得', '去', '的', '公司', '？']
# https://www.ptt.cc/bbs/Tech_Job/M.1474803612.A.2C8.html
# 83
# ['[', '閒聊', ']', ' ', '高捷', '捷運', '失火']
# https://www.ptt.cc/bbs/Kaohsiung/M.1486794377.A.B90.html
# 5
# ['[', '閒聊', ']', ' ', '愛買', '高雄店', '要', '吹', '熄燈號', '了']
# https://www.ptt.cc/bbs/Kaohsiung/M.1473425125.A.E31.html
# 6
# ['[', '發問', ']', ' ', '高雄', '抓百變', '怪', '推薦', '地點', '？']
# https://www.ptt.cc/bbs/PokemonGO/M.1479996044.A.A11.html
# 6
# ['[', '請益', ']', ' ', '為', '什麼', '台', '中', '房價', '會', '比高', '雄高', '？']
# https://www.ptt.cc/bbs/home-sale/M.1473258500.A.DEB.html
# 9
# ['[', 'BOX', ' ', ']', ' ', '2017', '年', '中職', '日職', '對抗賽', ' ', 'Game1']
# https://www.ptt.cc/bbs/Baseball/M.1488289500.A.F66.html
# 155
# ['[', '影音', ']', '[', ' ', 'GOT7', ' ', ']', ' ', '170410', ' ', 'Ask', ' ', 'in', ' ', 'a', ' ', 'Box', ' ', 'GOT7', '篇']
# https://www.ptt.cc/bbs/JYPnation/M.1491811280.A.7AF.html
# 9
# ['[', '影音', ']', ' ', '170328', ' ', '1theK', ' ', 'ASK', ' ', 'IN', ' ', 'A', ' ', 'BOX', ' ', 'HIGHLIGHT']
# https://www.ptt.cc/bbs/HIGHLIGHT/M.1490688129.A.AAF.html
# 3
# ['[', '心得', ']', ' ', 'MEIBE', ' ', 'BOX', ' ', '美妝盒', '，', '真的', '划算', '嗎', '？']
# https://www.ptt.cc/bbs/MakeUp/M.1465313353.A.1F2.html
# 71
# ['[', 'BOX', ']', ' ', '湘北', 'BOX']
# https://www.ptt.cc/bbs/YH33rd319/M.1327164169.A.623.html
# 26
# ['[', 'BOX', ' ', ']', ' ', 'Ｃ', 'Ｐ', 'Ｂ', 'Ｌ', ' ', '８', '：', '５', ' ', 'Ｊ', 'Ｐ', 'Ｎ', ' ', '[', 'email', '\xa0', 'protected', ']', '/', '*', ' ', '<', '!', '[', 'CDATA', '[', ' ', '*', '/', '!', 'function', '(', 't', ',', 'e', ',', 'r', ',', 'n', ',', 'c', ',', 'a', ',', 'p', ')', '{', 'try', '{', 't', '=', 'document', '.', 'currentScript', '|', '|', 'function', '(', ')', '{', 'for', '(', 't', '=', 'document', '.', 'getElementsByTagN']
# https://www.ptt.cc/bbs/Baseball/M.1488289530.A.975.html
# 110
# ['[', '影音', ']', ' ', '170310', ' ', '1theK', ' ', 'ASK', ' ', 'IN', ' ', 'A', ' ', 'BOX', ' ', 'BTOB', '_', 'MOVIE']
# https://www.ptt.cc/bbs/BTOB/M.1489133053.A.7FE.html
# 5
# ['[', 'BOX', ' ', ']', ' ', '2016', '-', '17', ' ', 'SBL', '例行', '賽', ' ', '璞園', ' ', '86', ' ', 'vs', ' ', '94', ' ', '台銀', ' ']
# https://www.ptt.cc/bbs/basketballTW/M.1487335525.A.E37.html
# 88
# ['[', '閒聊', ']', ' ', '山本', '的', 'BOX']
# https://www.ptt.cc/bbs/PuzzleDragon/M.1443276798.A.CE7.html
# 15
# ['[', 'BOX', ' ', ']', ' ', '克里夫蘭', ' ', 'VS', ' ', '印第安納']
# https://www.ptt.cc/bbs/NBA/M.1492739415.A.37D.html
# 33
