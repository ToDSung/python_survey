# %%
import MySQLdb
import requests
import urllib.parse
import time
from bs4 import BeautifulSoup
from selenium import webdriver

#conn = MySQLdb.connect(host="localhost", user="root", passwd="", db="python",charset='utf8')#連結資料庫
#cur = conn.cursor()

Google_url='https://www.google.com/'
mobile01_url='https://www.mobile01.com/'
sqli = "insert into mobile01 (key_word,search_title,search_href,search_time,search_author,article_picture,author_href,search_view) values (%s,%s,%s,%s,%s,%s,%s,%s)" #選擇資料表

#driver=webdriver.Chrome(executable_path=r'E://chromedriver') #模擬瀏覽器
driver=webdriver.PhantomJS(executable_path=r'E://phantomjs/bin/phantomjs') #模擬瀏覽器
driver.maximize_window()

key_word='咖哩'
payload={'q':key_word,'site':'site:https://www.mobile01.com/'}
q1=urllib.parse.quote(payload['q']) #url編碼轉換
url='https://google.com.tw/search?q='+q1+'+'+payload['site']
driver.get(url)

print(url)

page=1
for change in range(2,4):
    pageSource = driver.page_source #重新讀取當前頁面
    soup = BeautifulSoup (pageSource, "lxml") #流入BeautifulSoup

    for link in soup.select('.r'):
        
        #ChromeDriver
        #search_href=link.find('a')['href']
        
        
        #PhantomJS
        search_href=Google_url + link.find('a')['href']
        print(search_href)
        res=requests.get(search_href)
        res.encoding='utf-8'
        soup2 = BeautifulSoup (res.text, "lxml")
        for Main_article in soup2.find_all('main'):
            href_split=search_href.split('%')
            print(href_split)
            #if href_split[0]=='https://www.mobile01.com/topicdetail.php':
            if href_split[0]=='https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php'||href_split[0]=='https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php':
                #標題
                search_title=Main_article.select('.topic')[0].text
                print(search_title)
                #作者、作者網址
                authors = Main_article.select('.inner')
                author_name = authors[0].select('.fn')
                search_author=author_name[0].find('a').text
                author_href=mobile01_url+author_name[0].find('a')['href']
                
                #人氣
                info=authors[0].select('.info')
                search_view=info[0].text.strip('文章人氣:').lstrip().replace(',','')
                #文章時間
                time1=authors[0].select('.date')
                search_time=time1[0].text.strip('#1')
                #文章圖片
                post = Main_article.select('.single-post-content')
                if post[0].find('img')!=None:
                    picture=post[0].find('img')['src'].strip()
                    split=picture.split('/')
                    if split[2]=='attach.mobile01.com':
                        article_picture='https:'+picture
                    elif split[2]=='download.mobile01.com':
                        article_picture='https:'+picture
                    elif split[2]=='attach2.mobile01.com':
                        article_picture='./img/mobile01.jpg'
                    else:
                        article_picture=picture
                else:
                    article_picture='./img/mobile01.jpg'
                #cur.execute(sqli,(key_word,search_title,search_href,search_time,search_author,article_picture,author_href,search_view)) #存入資料庫    
                #conn.commit()
        time.sleep(0.5)
                    
    

    a=repr(change)
    driver.find_element_by_link_text(a).click() #點擊下一頁
    print('此處頁數為第',page,'頁')
    page+=1
    print ("===============================================================================================================")

driver.close();
#cur.close() #斷開連結
#conn.close()
# Out:
# https://google.com.tw/search?q=%E5%92%96%E5%93%A9+site:https://www.mobile01.com/
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D602%26t%3D4523311&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFggTMAA&usg=AFQjCNGwsul2EkNQEueslMYbtPClAQaLxA
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D602', '26t', '3D4523311&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFggTMAA&usg=AFQjCNGwsul2EkNQEueslMYbtPClAQaLxA']
# 食戟之靈-土豪金的龍蝦咖哩
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D37%26t%3D1128622&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFggZMAE&usg=AFQjCNHmG2TdA5eo2_L8EDu6rDUd0VyIjQ
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D37', '26t', '3D1128622&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFggZMAE&usg=AFQjCNHmG2TdA5eo2_L8EDu6rDUd0VyIjQ']
# [分享]電磁爐煮出平價克難咖哩
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D602%26t%3D2778831&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFggfMAI&usg=AFQjCNE5EZVUR3uhmmNBFWWOL3Cf_kh4RQ
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D602', '26t', '3D2778831&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFggfMAI&usg=AFQjCNE5EZVUR3uhmmNBFWWOL3Cf_kh4RQ']
# 關於咖哩的問題
# https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php%3Ff%3D197%26t%3D4996234&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFgglMAM&usg=AFQjCNGcSivQl6GiMF6wTxfEVFun-gaZbA
# ['https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php', '3Ff', '3D197', '26t', '3D4996234&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFgglMAM&usg=AFQjCNGcSivQl6GiMF6wTxfEVFun-gaZbA']
# ['https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php', '3Ff', '3D197', '26t', '3D4996234&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFgglMAM&usg=AFQjCNGcSivQl6GiMF6wTxfEVFun-gaZbA']
# https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php%3Ff%3D201%26t%3D5053297&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFggrMAQ&usg=AFQjCNEpMOja75-eFCk_KHitN_pIYhmEyw
# ['https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php', '3Ff', '3D201', '26t', '3D5053297&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFggrMAQ&usg=AFQjCNEpMOja75-eFCk_KHitN_pIYhmEyw']
# ['https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php', '3Ff', '3D201', '26t', '3D5053297&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFggrMAQ&usg=AFQjCNEpMOja75-eFCk_KHitN_pIYhmEyw']
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D602%26t%3D2190741&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFggxMAU&usg=AFQjCNEMoD5E9Z4ub1-rRd1GodNRPhniUg
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D602', '26t', '3D2190741&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFggxMAU&usg=AFQjCNEMoD5E9Z4ub1-rRd1GodNRPhniUg']
# 非常之簡單的"香噴噴咖哩飯"
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D37%26t%3D773088&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFgg3MAY&usg=AFQjCNHFNpOn9AjfZas9iQMheEBTRqW_0A
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D37', '26t', '3D773088&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFgg3MAY&usg=AFQjCNHFNpOn9AjfZas9iQMheEBTRqW_0A']
# 求咖哩達人做好吃的咖哩怎麼做?
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D330%26t%3D471294&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFgg9MAc&usg=AFQjCNFK70eq9IlGxDF-9yZUYixyFF0bLA
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D330', '26t', '3D471294&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFgg9MAc&usg=AFQjCNFK70eq9IlGxDF-9yZUYixyFF0bLA']
# 吃素的(咖哩)該放什麼料阿??..除了紅蘿蔔漢馬鈴薯..
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D602%26t%3D4041513&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFghDMAg&usg=AFQjCNGkOkSnFcLzWhl9qUjyti3PhXs0Ow
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D602', '26t', '3D4041513&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFghDMAg&usg=AFQjCNGkOkSnFcLzWhl9qUjyti3PhXs0Ow']
# 食戟之靈-創真的咖哩蛋包飯
# https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php%3Ff%3D345%26t%3D3933166&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFghJMAk&usg=AFQjCNF-yDEod4-QREZKEFJbtlc7JudItA
# ['https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php', '3Ff', '3D345', '26t', '3D3933166&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFghJMAk&usg=AFQjCNF-yDEod4-QREZKEFJbtlc7JudItA']
# ['https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php', '3Ff', '3D345', '26t', '3D3933166&sa=U&ved=0ahUKEwjRsOeQtt3TAhUGpJQKHQTEAbYQFghJMAk&usg=AFQjCNF-yDEod4-QREZKEFJbtlc7JudItA']
# 此處頁數為第 1 頁
# ===============================================================================================================
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D37%26t%3D5061998&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCBMwAA&usg=AFQjCNFPWvpsB7NfqT6uS9f1E5-Ekzk0ig
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D37', '26t', '3D5061998&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCBMwAA&usg=AFQjCNFPWvpsB7NfqT6uS9f1E5-Ekzk0ig']
# 『咖喱飯』售價成本好像很低.....但是有的地方賣超貴又不好吃！！！
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D602%26t%3D2337161&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCBkwAQ&usg=AFQjCNF2kx41SKORpI3HhmG1WUMgT6z_FQ
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D602', '26t', '3D2337161&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCBkwAQ&usg=AFQjCNF2kx41SKORpI3HhmG1WUMgT6z_FQ']
# 大家煮咖哩飯的時候喜歡加什麼食材呢??
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D291%26t%3D1357892&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCB8wAg&usg=AFQjCNEvaIeQ5BQeIrDtPWzCT0XBEq4U6A
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D291', '26t', '3D1357892&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCB8wAg&usg=AFQjCNEvaIeQ5BQeIrDtPWzCT0XBEq4U6A']
# 開一家日式咖哩餐廳，大約需要多少資金？有那些要注意的呢？
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D602%26t%3D3878914&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCCUwAw&usg=AFQjCNF6NrqV0tMlhpwlo3G124gOTHABcw
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D602', '26t', '3D3878914&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCCUwAw&usg=AFQjCNF6NrqV0tMlhpwlo3G124gOTHABcw']
# 小惡魔料理分享 超簡易泰式咖哩
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D602%26t%3D3744385&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCCswBA&usg=AFQjCNEyxMa0qT6v38pOmjLZHvisc_GBuQ
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D602', '26t', '3D3744385&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCCswBA&usg=AFQjCNEyxMa0qT6v38pOmjLZHvisc_GBuQ']
# 【食譜】日本２段熟咖哩，簡單上桌！
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D602%26t%3D4293261&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCDEwBQ&usg=AFQjCNG_M0899Un-4lWfz6cxaB6ZbpOGGg
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D602', '26t', '3D4293261&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCDEwBQ&usg=AFQjCNG_M0899Un-4lWfz6cxaB6ZbpOGGg']
# 分享好吃的百勝廚新加坡咖哩
# https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php%3Ff%3D204%26t%3D2718054&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCDcwBg&usg=AFQjCNGGJ2shB2LUpFG-ruuugmuCF1xHMw
# ['https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php', '3Ff', '3D204', '26t', '3D2718054&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCDcwBg&usg=AFQjCNGGJ2shB2LUpFG-ruuugmuCF1xHMw']
# ['https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php', '3Ff', '3D204', '26t', '3D2718054&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCDcwBg&usg=AFQjCNGGJ2shB2LUpFG-ruuugmuCF1xHMw']
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D602%26t%3D2589742&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCDwwBw&usg=AFQjCNHu-uXNSBZbVA0DmW_VoteMpi9--w
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D602', '26t', '3D2589742&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCDwwBw&usg=AFQjCNHu-uXNSBZbVA0DmW_VoteMpi9--w']
# 每個人家裡都有的私房菜-日式咖哩的祕密
# https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php%3Ff%3D197%26t%3D4648922&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCEIwCA&usg=AFQjCNEraJWwFpdYmjPuajVwiIogIqy4Pw
# ['https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php', '3Ff', '3D197', '26t', '3D4648922&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCEIwCA&usg=AFQjCNEraJWwFpdYmjPuajVwiIogIqy4Pw']
# ['https://www.google.com//url?q=https://www.mobile01.com/waypointtopicdetail.php', '3Ff', '3D197', '26t', '3D4648922&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCEIwCA&usg=AFQjCNEraJWwFpdYmjPuajVwiIogIqy4Pw']
# https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php%3Ff%3D602%26t%3D4382303&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCEgwCQ&usg=AFQjCNFPxrUmZ4mZqyzXlWecSDPAeJoQ3Q
# ['https://www.google.com//url?q=https://www.mobile01.com/topicdetail.php', '3Ff', '3D602', '26t', '3D4382303&sa=U&ved=0ahUKEwi00qSVtt3TAhUJm5QKHa19Bp04ChAWCEgwCQ&usg=AFQjCNFPxrUmZ4mZqyzXlWecSDPAeJoQ3Q']
# 咖哩飯配什麼湯比較合
# 此處頁數為第 2 頁
# ===============================================================================================================
