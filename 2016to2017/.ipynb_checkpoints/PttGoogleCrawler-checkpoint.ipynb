# %%
import re
import requests
import urllib.parse
import time
from bs4 import BeautifulSoup
from selenium import webdriver

def get_web_page(url): #原始地址
    #time.sleep()  # 每次爬取前暫停 0.5 秒以免被 PTT 網站判定為大量惡意爬取
    resp = requests.get(
        url=url,
        cookies={'over18': '1'}
    )
    #if resp.status_code != 200:
    #    print('Invalid url:', resp.url)
    #    return resp.text
    #else:
    return resp.text


#driver=webdriver.Chrome(executable_path=r'E://chromedriver') #模擬瀏覽器
driver=webdriver.PhantomJS(executable_path=r'E://phantomjs/bin/phantomjs') #模擬瀏覽器

driver.maximize_window()
x=input()
payload={'q':x,'site':'site:ptt.cc/'}
q1=urllib.parse.quote(payload['q']) #url編碼轉換
url='https://google.com.tw/search?q='+q1+'+'+payload['site']
driver.get(url)

page=1
for change in range(2,3):
    
    
    pageSource = driver.page_source #重新讀取當前頁面
    soup = BeautifulSoup (pageSource, "html5lib") #流入BeautifulSoup

    for object in soup.select('div.g'):
        for link in object.find_all('cite'):
            search_href=link.text
            soup2=BeautifulSoup(get_web_page(search_href), "html5lib")
            Push_Count=0
            Boo_Count=0
            Arrow_Count=0
            data =soup2.select('span[class="article-meta-value"]')
            if data!=[]:
                if len(data)==3:
                    data.insert(1,'unknown')
                    Board=data[1]
                else:
                    Board=data[1].get_text()
                Author=data[0].get_text()
                Title=data[2].get_text()
                Time=data[3].get_text()

                print(search_href)
                print('標題:'+repr(Title)+'看板:'+repr(Board)+'作者:'+repr(Author)+'時間:'+repr(Time))

                for PushTag in soup2.select('span[class="hl push-tag"]'):
                    Push_Count+=1
                for RedTag in soup2.select('span[class="f1 hl push-tag"]'):
                    if RedTag.text.strip()=='噓':
                        Boo_Count+=1 
                    else:
                        Arrow_Count+=1    
                print('推:'+repr(Push_Count))
                print('噓:'+repr(Boo_Count))
                print('箭頭:'+repr(Arrow_Count))
            

    a=repr(change)
    driver.find_element_by_link_text(a).click() #點擊下一頁
    print('此處頁數為第',page,'頁')
    page+=1
    time.sleep(2)
    print ("===============================================================================================================")

driver.close();
# Out:
# 麵包
# https://www.ptt.cc/bbs/Gossiping/M.1487646506.A.97B.html
# 標題:'[新聞] 拍扁麵包師的麵包長這樣\u3000網友看完崩潰了'看板:'Gossiping'作者:'emou (snoitome eurt deen I)'時間:'Tue Feb 21 11:08:19 2017'
# 推:90
# 噓:8
# 箭頭:31
# https://www.ptt.cc/bbs/Gossiping/M.1487604802.A.B40.html
# 標題:'Re: [新聞] 拍扁麵包師黃士福又出聲證實白狼援助30萬'看板:'Gossiping'作者:'bigbear2007 (哇最愛逮完)'時間:'Mon Feb 20 23:33:18 2017'
# 推:224
# 噓:8
# 箭頭:40
# https://www.ptt.cc/bbs/Gossiping/M.1477991370.A.866.html
# 標題:'[爆卦] 記者看過來，檢舉麵包師的權貴在此!!!!'看板:'Gossiping'作者:'EZyou (===★追夢人★===)'時間:'Tue Nov  1 17:09:26 2016'
# 推:902
# 噓:93
# 箭頭:137
# https://www.ptt.cc/bbs/Gossiping/M.1477909611.A.EAE.html
# 標題:'[問卦] 麵包師傅的推銷術'看板:'Gossiping'作者:'clark0816 (阿杯)'時間:'Mon Oct 31 18:26:48 2016'
# 推:52
# 噓:4
# 箭頭:30
# https://www.ptt.cc/bbs/StupidClown/M.1484580448.A.96A.html
# 標題:'[大哭] 麵包超人手機殼'看板:'StupidClown'作者:'pipi0903 (pipi0903)'時間:'Mon Jan 16 23:27:25 2017'
# 推:58
# 噓:11
# 箭頭:9
# https://www.ptt.cc/bbs/LineGames/M.1467547978.A.B97.html
# 標題:'[問題] 波蘿麵包缺一材料哪裡生?'看板:'LineGames'作者:'Salvia41 (小靜學姊)'時間:'Sun Jul  3 20:12:56 2016'
# 推:2
# 噓:0
# 箭頭:2
# https://www.ptt.cc/bbs/joke/M.1483973548.A.A39.html
# 標題:'[猜謎] 麵包超人加一'看板:'joke'作者:'yurmom (媽媽樂天派)'時間:'Mon Jan  9 22:52:24 2017'
# 推:116
# 噓:53
# 箭頭:19
# https://www.ptt.cc/bbs/CVS/M.1481187259.A.270.html
# 標題:'[商品] 7-11青蔥乳酪麵包'看板:'CVS'作者:'cadmus22 (mdn頭家)'時間:'Thu Dec  8 16:54:17 2016'
# 推:16
# 噓:0
# 箭頭:2
# https://www.ptt.cc/bbs/StupidClown/M.1490691179.A.25E.html
# 標題:'[大哭]  我以為我做的是麵包'看板:'StupidClown'作者:'sodapin (你說什麼 YO)'時間:'Tue Mar 28 16:52:56 2017'
# 推:62
# 噓:0
# 箭頭:12
# 此處頁數為第 1 頁
# ===============================================================================================================
