# %%
import requests


res=requests.get('http://blog.xuite.net/rubyintainan/blog/498867118')
res.encoding='utf-8'
print (res.text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd"><html
# lang="zh_TW"><head><meta
# http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta
# name="keywords" content="部落格,網誌,PIXNET,痞客邦,痞客幫,痞克邦,痞克幫,痞客,痞克,相簿,免費,影音,"><meta
# name="description" content="最豐富最多樣內容,集合網友嘔心瀝血之作,點閱率居高不下,偶像名人也紛紛加入這股痞客邦 PIXNET 風潮,你也可以創造一個個人專屬創作的天地"><title>搜尋結果  :: 痞客邦 PIXNET ::</title><link
# rel="stylesheet" href="//mainpage.pixfs.net/search/style/construction.css?v=4d55c9dd375d769b40a8ffc436e1554c" type="text/css"><link
# rel="stylesheet" href="//mainpage.pixfs.net/css/main.min.css?v=4d55c9dd375d769b40a8ffc436e1554c" type="text/css"><link
# rel="stylesheet" href="//mainpage.pixfs.net/index/style/index.min.css?v=4d55c9dd375d769b40a8ffc436e1554c"><link
# rel="stylesheet" href="//front.pixfs.net/module/topbar/css/blogtopbar.min.css?v=4d55c9dd375d769b40a8ffc436e1554c"><link
# ...
