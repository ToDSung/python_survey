# %%
import requests
import MySQLdb
from bs4 import BeautifulSoup
import jieba
import jieba.analyse

def remove_values_from_list(the_list, val):
    return [value for value in the_list if value != val]

def get_web_page(url): #原始地址
    time.sleep(0.5)  # 每次爬取前暫停 0.5 秒以免被 PTT 網站判定為大量惡意爬取
    resp = requests.get(
        url=url,
        cookies={'over18': '1'}
    )
    return resp.text

jieba.set_dictionary('dict.txt.big')
jieba.load_userdict('userdict.txt')

conn = MySQLdb.connect(host="localhost", user="root", passwd="", db="python",charset='utf8')#連結資料庫
cur = conn.cursor()
cur.execute("SELECT search_href,id FROM pixnet")
results = cur.fetchall()

with open('list.txt', 'r',encoding='UTF-8') as list:
    list1=[]
    for line in list:
        list1.append(line.strip('\ufeff').strip())
    list.close()
'''    
for record in results:    
db_url = record[0]
ixnet_id = record[1]
res=requests.get(db_url)
res.encoding='utf-8'
soup = BeautifulSoup (res.text, "html5lib")
soup2 =  soup.select('meta')[1]

original_url =soup2['content'].lstrip('3;url=')
'''
original_url='http://dressingfrad.pixnet.net/blog/post/447959588-%E4%B8%AD%E5%92%8C-%E6%AD%A6%E4%BB%95%E6%97%A5%E5%BC%8F%E7%82%AD%E7%81%AB%E7%87%92%E8%82%89-%E7%87%92%E8%82%89%E7%81%AB%E9%8D%8B%E5%90%83%E5%88%B0%E9%A3%BD-%E6%AF%94%E8%87%89'
print (original_url)

res1=requests.get(original_url)
res1.encoding='utf-8'
soup1 = BeautifulSoup (res1.text, "html5lib")
#內文
main_article = soup1.select('.article-content-inner')    

content=main_article[0].text.strip()
sentence=content.split("\n")
sentence=remove_values_from_list(sentence,'')


total_count=0
for line in sentence:

    line2=line.strip()
    words=jieba.lcut(line2, cut_all=False)
    print(words)
    s1 = set(list1)
    s2 = set(words)
    intersection=s1.intersection(s2)
    count=len(intersection)
    total_count=total_count+count
print(total_count)
# Out:
# http://dressingfrad.pixnet.net/blog/post/447959588-%E4%B8%AD%E5%92%8C-%E6%AD%A6%E4%BB%95%E6%97%A5%E5%BC%8F%E7%82%AD%E7%81%AB%E7%87%92%E8%82%89-%E7%87%92%E8%82%89%E7%81%AB%E9%8D%8B%E5%90%83%E5%88%B0%E9%A3%BD-%E6%AF%94%E8%87%89
# Building prefix dict from C:\Users\wlunareve\python\dict.txt.big ...
# Loading model from cache C:\Users\WLUNAR~1\AppData\Local\Temp\jieba.ube0c4e67d291f94013d7023df2b3161e.cache
# Loading model cost 1.405 seconds.
# Prefix dict has been built succesfully.
# ['中', '和', '/', '永和', ' ', '\xa0', '燒肉', '吃', '到', '飽', '，', '單人', '不', '加價', '，']
# ['雙人', '還可', '追加', '火鍋', '燒烤', '通殺', '吃', '到', '飽', '，']
# ['而且', '中午', '沒有', '休息', '，', '下午茶', '也', '可', '以來', '一場', '吃', '到', '飽', '，', '就是', '武仕', '日式', '炭火', '燒肉']
# []
# []
# []
# ['一整天', '都', '沒', '休息', '的燒', '肉店']
# ['從中', '午', '就', '可以', '開始', '大', '吃', '的', '感覺', '真', '好']
# ['有', '菜單', '可以', '先', '參考']
# []
# []
# []
# ['店內', '主要', '都', '是', '四人', '座位', '為主']
# ['每個', '座位', '區都', '有', '專屬', '烤爐', '的', '抽', '煙機']
# ['直接', '把', '烤肉', '煙', '吸走']
# []
# []
# []
# ['位子', '間距', '還', 'ok', ' ', '店內', '也', '都', '有', '放', '音樂']
# ['所以', '不', '擔心', '會', '聽到', '隔壁', '的', '談話']
# []
# []
# ['飲料', '有', '果汁', '\u3000', '日式', '煎', '茶']
# ['玻璃瓶', '裝的', '可口可樂', '\u3000', '雪碧', '\u3000', '芬達']
# []
# []
# ['冰淇淋', '則是', '明治', '冰淇淋']
# ['而且', '有', '10', '種', '口味', '也', '太', '齊全']
# ['光是', '吃', '冰', '就', '可以', '品嘗好', '一陣子']
# []
# []
# []
# ['不', '只', '一樓', '有', '位子']
# ['武仕', '日式', '炭火', '燒肉', '還有', '二樓', '喔']
# ['座位', '區', '空間', '也', '更', '大', '了']
# []
# []
# []
# ['除了', '一', '整排']
# ['有', '木頭', '隔間', '有點', '像是', '包廂', '之外']
# []
# []
# []
# ['最後', '方', '還有', '一', '區塊']
# ['是', '可以', '三桌', '一起', '的', '烤肉', '區塊']
# ['很', '適合', '聚餐', '大家', '一起', '烤', '感情', '比較', '好']
# []
# []
# ['武仕', '日式', '炭火', '燒肉', '使用', '的', '是', '木炭', '炭火', '烤爐']
# ['最', '底下', '會', '舖', '上', '隔熱', '墊材']
# ['上', '方才', '是', '熱熱', '烤爐']
# []
# []
# ['吃', '到', '飽', '菜單', '很', '重要']
# ['這裡', '有', '兩種', '選擇', ' ', '599', '+', '10', '%']
# ['牛板腱', ' ', '牛小排', ' ', '豬', '霜降', ' ', '菲力豬', ' ', '羊', '雪花', ' ', '羊', '肋排']
# ['雞肉', '有', '不同', '調味', '和', '軟骨']
# ['海鮮', '則是', '花枝', '白蝦', '圓鱈生', '蠔通', '通來', '了']
# []
# []
# []
# ['另外', '還有', '蔬菜', ' ', '奶油', '金針菇', ' ', '波浪', '馬鈴薯', ' ', '杏鮑菇', ' ', '甜不辣']
# ['煮', '火鍋', '也', '有', '各種', '火鍋', '配料']
# ['單點', '則是', '有', '深海', '大', '草蝦', ' ', '日本', '大干', '貝', ' ', '巨無霸', '牛排']
# ['各種', '酒精性', '飲料', ' ', '是', '說生', '啤', '也', '太', '便宜', '才', '80', ' ', '而且', '好像', '有', '買一送一', '!']
# ['(', '喝酒', '不', '開車', '開車', '不', '喝酒', ')']
# []
# []
# []
# ['749', '+', '10', '%', '的', '組合']
# ['則是', '多', '了', '和', '牛', '前胸', '肉', ' ', '炙燒', '雪花', '牛']
# ['無骨', '牛小排', ' ', '翼板', '牛', ' ', '以及', '厚切', '牛舌']
# ['豬肉', '有', '單骨', '豬排', ' ', '鹹豬肉', ' ', '海鮮', '則是', '多', '了', '白玉', '干貝', ' ', '香魚', '和', '天使', '紅蝦']
# []
# []
# []
# ['店家', '會先', '詢問', '是否', '要', '直接', '上', '一些', '經典', '款']
# ['那', '就', '來', '吧', '!', '開烤', '囉']
# []
# []
# ['泰式', '酸辣', '雞']
# ['已經', '有', '先', '調味', '過', ' ', '吃', '起來', '味道', '不會', '太重']
# ['帶點', '酸甜', '感', '開胃']
# []
# []
# ['厚切', '牛舌']
# ['不用', '太熟', '是', '重點', ' ', '帶點', '厚度', '的', '脆口', '柔軟']
# ['一定', '要', '搭配', '店家', '自調', '的', '洋蔥', '蔥花', ' ', '絕配', '~']
# []
# []
# ['頂級', '翼板', '牛']
# []
# []
# []
# ['本日', '推推', ' ', '烤', '的', '剛好', '的', '粉嫩', '粉紅']
# ['一口', '吃掉', '兩三片', ' ', '那種', '屬於', '超好', '肉質', '的', '口感', ' ', '很', '值得', '再', '加點']
# []
# []
# []
# ['蔬菜', '也', '來', '了']
# ['杏鮑菇', '有', '先', '經過', '調味', ' ', '多汁', '水分']
# []
# []
# []
# ['霜降', '豬']
# ['就是', '要切', '的', '這麼', '大塊', ' ', '吃', '起來', '才', '有', '爽度', '啊']
# ['油嫩', '外加', '油花', '分布', ' ', '咬起來', '可是', '有', '肉汁', '的', '喔']
# []
# []
# []
# ['首波', '大', '魔王']
# ['嚴選', '和', '牛', '前胸', '肉']
# []
# []
# []
# ['有', '多', '大', '!', '一片', '都', '快要', '跟', '盤子', '一樣', '長寬', '高', '了']
# ['用', '躺', '著', '看不出來', '嗎', ' ', '拿', '起來', '看看', ' ', '\xa0', '就是', '這麼', '大', '~']
# []
# []
# ['烤爐', '瞬間', '被', '兩片', '肉', '占', '據', '整個', '版面']
# ['是', '有沒有', '這麼', '很', '適合', '躺', '一下', '的', '棉被', '感']
# []
# []
# ['烤完', '不縮水', ' ', '還是', '一樣', '超', '大片']
# ['都', '想要', '借', '把', '剪刀', ' ', '不然', '這麼', '大片', '是', '要', '怎麼', '吃', '啦']
# []
# ['姐', '還是', '認真', '的', '捲', '一', '捲', ' ', '分', '了', '好幾口']
# ['邊', '邊', '油花', '和', '稍微', '緊實', '的', '肉質']
# ['雖然', '面積', '很', '驚人', ' ', '但', '很', '適合', '拿來', '打卡', '拍照']
# []
# ['海鮮', '組', '登場']
# ['草蝦', '和', '天使', '紅蝦', ' ', 'size', '大小', '比一比']
# []
# []
# ['不同', '蝦', '蝦', ' ', '吃', '起來', '的', '肉質', '和', '甜度']
# ['都', '有', '些許', '不同', ' ', '大尾', '的', '天使', '紅蝦', '真的', '甜']
# ['草蝦', '肉質', '也', '很', '不錯', ' ', '而且', '新鮮', '好', '剝']
# []
# []
# ['是', '的', '澎湖', '來', '的', '生', '蠔', '也', '請勿', '忘記', '一起', '烤', '吧', '烤', '吧']
# ['最好', '是', '烤', '到', '裡面', '的', '湯汁', ' ', '咕嚕咕嚕', '熱', '起來']
# ['就', '可以', '準備', '開台', '囉']
# []
# []
# ['跟', '著海裡', '的', '鮮甜', '一起', '入口', '吧', '大海', '的', '牛奶', '們']
# []
# []
# []
# ['加點', '第二', '波', ' ', '首先', '是']
# ['香', '滷', '肥腸']
# ['切', '的', '算', '大塊', ' ', '處理', '的', '也', '乾淨']
# ['烤', '的', '邊邊', '脆脆', '焦焦', ' ', '非常適合', '配', '氣泡', '式', '飲料']
# []
# []
# []
# ['蛋蛋', '柳葉魚']
# ['不', '小心', '就', '忘記', '拍', '成品', '了']
# ['但', '真的', '有', '滿滿', '蛋蛋', ' ', '雖然', '有點', '罪惡感', ' ', '但', '還真好', '粗']
# []
# []
# ['京都', '香魚']
# ['好像', '是', '第一次', '在', '燒烤', '吃', '到', '飽', '的', '店裡', '看到', '香魚', '的', '選項', '耶']
# ['當然', '要點', '一下', '囉', ' ', '表面', '已經', '有灑', '上', '鹽巴', '避免', '沾', '黏']
# []
# []
# ['一整', '尾', '上桌', '覺得很有', '類', '日式', '料理店', '氣氛']
# ['把', '頭尾', '捏一捏', ' ', '就', '可以', '把', '骨頭', '取', '出來', '囉']
# ['肉質', '細緻', '好吃']
# []
# []
# ['吃', '完', '魚兒', '要來', '大口', '啃', '肉']
# ['法式', '單骨', '豬排']
# []
# []
# ['也', '是', '一個', '在', '比大', '的', '啦']
# ['而且', '不會', '太厚', '的', '豬排', ' ', '烤起來', '滋滋', '作響']
# ['很快', '就', '可以', '享用', '了']
# ['抓著', '骨頭', '一口', '咬下', '豬肉', '就是', '極致', '享受']
# []
# []
# ['櫻桃', '鴨']
# []
# ['感覺', '也', '是', '第一次', '看到', '這', '選項']
# ['而且', '雖然', '是', '鴨肉', ' ', '但是', '油花', '超多', ' ', '差點', '就要', '發爐', '了']
# []
# []
# []
# ['雖然', '走', '一個', '油花', '大', '噴發', '的', '概念']
# ['但', '吃', '起來', '並', '不會', '太', '油膩', '耶', ' ', '覺得', '很', '有趣']
# []
# []
# ['骰子', '牛', '肋條']
# ['四面', '煎', '一', '煎', '就', '可以', '吃', '了']
# ['算是', '比較', '肉', '纖維', '充足', '的', '一品']
# []
# []
# ['美式', '漢堡', '肉']
# ['厚切', '漢堡', '排', '很', '有感']
# ['跟', '骰子', '牛', '一樣', '一口', '一個', '剛剛', '好']
# []
# []
# ['中場', '休息時間', '~']
# ['明治', '冰淇淋', '登場', ' ', '力推', '巧克力', '口味']
# ['而且', '夠軟', '很', '好', '挖', '唷']
# []
# []
# ['加點', '第三輪', '開始']
# []
# ['白玉', '干貝']
# ['已經', '有', '調味', ' ', '烤起來', '脆脆', ' ', '很', '像', '在', '吃零食']
# []
# []
# ['真的', '零食', '在', '這裡']
# ['竟然', '有', ' ', '波浪', '馬鈴薯', '片', ' ', '超', '有趣', '的', '啊']
# ['真的', '就是', '洋芋片', '的', '感覺', '了', ' ', '這', '可以', '多', '烤', '幾份']
# []
# []
# ['德式', '煙燻', '豬腳']
# ['烤起來', '豬腳', '皮帶', '點厚', 'QQ']
# ['煙燻', '鹹度', '剛好']
# []
# []
# []
# ['炙燒', '雪花', '牛', ' ', '忽然', '又', '好', '大', '一盤', '登場', '了']
# []
# []
# ['烤', '10', '秒', ' ', '翻面', ' ', '再', '烤', '8', '秒']
# ['就', '可以', '吃', '囉']
# []
# ['加點', '了', '洋蔥', '絲', '一起', '搭配']
# ['沒有', '嗆', '味', '只有', '清甜', ' ', '很', '不錯']
# ['適合', '愛吃肉', '的', '朋友', '轉換', '口味', '用']
# []
# []
# ['最後', '加點', ' ', '爆漿', '雞腿', '捲']
# ['覺得', '太', '神祕', '了', '到底', '是', '甚麼', ' ', '沒想到', '是', '一', '整條']
# ['切', '開來', '發現', '原來', '是', '無骨', '雞腿', '直接', '捲成', '的']
# ['雞皮', '脆', '雞腿肉', '意外', '的', '還滿重', '鹹']
# []
# []
# []
# ['甜點', '時間', '~', ' ', '有', '棉花', '糖', ' ', '冰心', '地瓜', ' ', '麻', '糬']
# ['一人限點', '一份']
# []
# []
# []
# ['冰心', '地瓜', ' ', '可以', '直接', '冰冰', '吃', '就', '很', '好吃']
# ['也', '可以', '烤熱', '在', '吃', ' ', '烤', '熱版', '甜度', '倍增']
# []
# []
# []
# ['棉花', '糖要', '拿', '著', '烤']
# ['麻', '糬', '則', '是', '可以', '換', '四面', '翻轉', '烤']
# []
# []
# []
# ['棉花', '糖']
# ['只', '溶', '你', '口', '在', '口裡', '爆漿', '的', '感覺', '很', '不錯']
# []
# ['麻', '糬', '烤', '的', '澎', '澎']
# ['就', '可以', '沾', '煉乳', '和', '花生粉', '囉']
# ['真是', '絕對', '不', '失敗', '的', '一品']
# []
# []
# ['整體', '來說', ' ', '菜色', '很多', ' ', '而且', '還滿', '有', '特色']
# ['鮮度', '也夠', ' ', '換網', '快速', ' ', '經過', '也', '會', '幫忙', '注意', '肉品', '熟度']
# ['而且', '中午', '沒', '休息時間', '真是太', '好', '啦', '~']
# []
# ['武仕', '日式', '炭火', '燒肉', ' ', '吃', '到', '飽']
# ['https', ':', '/', '/', 'www', '.', 'facebook', '.', 'com', '/', 'wushihBBQ']
# ['地址', ':', '新北市', '中', '和', '區興', '南路', '一段', '7', '號', '1', '樓']
# ['電話', ':', '02', '-', '8941', '-', '9966']
# ['價位', ':', '559', '+', '10', '%', ' ', 'OR', ' ', '749', '+', '10', '%']
# ['單人', '開爐', '不', '加收', '費用', ' ', '如', '要', '加點', '火鍋', '+', '200', ' ', '雙人', '+', '火鍋', '免費']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['武仕', '日式', '炭火', '燒肉', ',', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '吃', '到', '飽', ',', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '燒烤', '吃', '到', '飽', ',', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '燒肉', '吃', '到', '飽', ',', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '火鍋', '吃', '到', '飽', ',', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '燒肉', '火鍋', '吃', '到', '飽', ',', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '中', '和', ',', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '永和', ',', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '南勢角', '車站', ',', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '南勢角']
# []
# ['創作者', '介紹']
# []
# []
# []
# []
# ['dressingfrad']
# []
# []
# []
# []
# []
# []
# []
# ['dressingfrad', '的', '不正', '食記', '分享']
# 0
