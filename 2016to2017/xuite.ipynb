# %%
#xuite
import MySQLdb
import sys
import requests
import urllib.parse
from bs4 import BeautifulSoup

#編碼使用
# url_key_word = sys.argv[1]
# chinese_key_word=urllib.parse.unquote(sys.argv[1])
url_key_word='麵包'


# conn = MySQLdb.connect(host="localhost", user="root", passwd="", db="python",charset='utf8')#連結資料庫
# cur = conn.cursor()
# sqli = "insert into xuite (key_word,search_title,search_subtitle,article_picture,search_href,search_author,author_href) values (%s,%s,%s,%s,%s,%s,%s)" #選擇資料表

page = '1'
payload={'type' : 'search','query':url_key_word, 'database':'haarticle','sort':'','p':page  }
res=requests.get("http://blog.xuite.net/new_index.php?",params=payload)
res.encoding='utf-8'
soup = BeautifulSoup (res.text, "html5lib")


for item in soup.select('div[class="n"]'):

#標題
    search_title = item.select('a')[2].text
    print (search_title)
    
#副標題
    search_subtitle = item.select('div[class="after_m_des"]')[0].text
    print (search_subtitle)
    
#網址
    search_href = item.find('a')['href']
    print (search_href)
    
#圖片    
    for img in item.select('div[class="after_m_photo"]'):
        article_picture = img.find('img')['src']
        print (article_picture)
        
#作者    
    search_author = item.select('div[class="after_r_id"]')[0].text
    print (search_author)
    
#作者網址
    for autor in item.select('div[class="after_r_id"]'):
        author_href = autor.find('a')['href']
        print (author_href)
#         cur.execute(sqli,(chinese_key_word,search_title, search_subtitle, article_picture, search_href, search_author, author_href)) #存入資料庫    
#         conn.commit()

# cur.close() #斷開連結
# conn.close()
# Out:
# 麵包
# 這是我做的麵包是蔓越莓和葡萄乾麵包
# http://blog.xuite.net/s100047/blog/416648923
# http://blog.xuite.net/s100047/blog/416648923/cover.jpg
# s100047stu.yfes.ntpc.edu.tw
# http://xuite.net/s100047
# 麵包店
# 今天我和家人一起出門走走我們看到了一間麵包店一進門就聞到一股淡淡的麵包香看看左右兩側哇一整排的麵包每一個麵包都好像在跟我招手好想吃每個麵包都好想吃我推薦大家也去吃吃看真的很好吃喔
# http://blog.xuite.net/djes1010193/blog/477414326
# http://blog.xuite.net/djes1010193/blog/477414326/cover.jpg
# djes1010193stu.djes.tyc.edu.tw
# http://xuite.net/djes1010193
# 菓子麵包(熊麵包）
# 菓子麵包※材料
# 1.隔夜中種(8-12小時)(70%): 高麵574克 乾酵母1.6克 水369克2.本種(30%): 高筋 246克 糖164克
# 鹽8克  乾酵母7克  牛奶82克(1克牛奶加9克
# http://blog.xuite.net/hellidog/wretch/497700002
# http://blog.xuite.net/hellidog/wretch/497700002/cover.jpg
# hellidog
# http://xuite.net/hellidog
# 做麵包
# 105.6.14  星期二用烤箱烤出來的麵包比麵包機好吃哦！至少不會有厚厚的、硬硬的一層 --「殼」前半段做法和麵包機做法一樣把材料全部放入麵包機-攪拌、醒麵團、發酵等發酵完成，再拿出來~分成兩份
# http://blog.xuite.net/a546348/blog/423699997
# http://blog.xuite.net/a546348/blog/423699997/cover.jpg
# 楊
# http://xuite.net/a546348
# 麻花麵包整形
# 各種麻花餐包，只要自己喜歡都可以。簡單又有趣！請用任何麵包的配方或參考牛奶麵包的食譜。八條辮子四條辮子的作法
# http://blog.xuite.net/d840705/twblog1/493854750
# http://blog.xuite.net/d840705/twblog1/493854750/cover.jpg
# 微笑安妮smile_Annie
# http://xuite.net/d840705
# 大人氣麵包
# 六本木賞櫻期間, 在會議中心見到這法國麵包店, MAISON KAYSER (Paris). 人氣 No. 3 呢款麵包, 芝士味, 少少咸, 外脆內軟,
# 正到唔識形容.www
# http://blog.xuite.net/stacy6905/hkblog1/498788974
# http://blog.xuite.net/stacy6905/hkblog1/498788974/cover.jpg
# stacy6905
# http://xuite.net/stacy6905
# 南瓜麵包
# 南瓜麵包南瓜餡是夏天自菜園採收的南瓜,因為吃不完,我便將其作成南瓜餡後分袋包裝冷凍保存,隨時都可拿來做好吃的包入滿滿的南瓜餡麵包.
# http://blog.xuite.net/ritaju/twblog/467117406
# http://blog.xuite.net/ritaju/twblog/467117406/cover.jpg
# ritaju
# http://xuite.net/ritaju
# 韓國麵包
# 好玩，好奇。。。。。做了很簡單的韓國麵包，剛出爐又香又酥又Q，忍不住要吞一個呢！韓國麵包粉   250克高筋麵粉
#   40克蛋         1個牛奶
#  50克奶油      50克黑
# http://blog.xuite.net/ritaju/twblog/466989758
# http://blog.xuite.net/ritaju/twblog/466989758/cover.jpg
# ritaju
# http://xuite.net/ritaju
# 烤焦麵包
#   烤焦麵包式我覺得最可愛DER的書，作者也把自己畫的很像麵包，有一寫現實沒有的麵包都看起來很好吃，他還有說位神麼會烤焦呢？因為拿出來時不小心又掉進去了，有些很完美，有些很焦，但很可愛愛♥，我真的很
# http://blog.xuite.net/mars1212618/mars/480495075
# http://blog.xuite.net/mars1212618/mars/480495075/cover.jpg
# mars1212apps.ntpc.edu.tw
# http://xuite.net/mars1212618
# 花式麵包
# 花式麵包啦.首先食材:
#         高筋麵粉:270g
#  低筋麵粉:  30g          糖
#       : 30g         橄欖油
#    :30g
# http://blog.xuite.net/b4187/lito6025/475002137
# http://blog.xuite.net/b4187/lito6025/475002137/cover.jpg
# 秀
# http://xuite.net/b4187
# 菠蘿麵包
# 之前一直有朋友要我做菠蘿麵包...但其實我不算很喜歡那層皮而且老實說...那層菠蘿皮還蠻..油的說之所以會做..完全是因為半夜睡不著..開著電視剛好播出蔡季芳老師在教如何製作菠蘿麵包另一個原因是
# http://blog.xuite.net/calla0430/Summer/453306661
# http://blog.xuite.net/calla0430/Summer/453306661/cover.jpg
# Summer
# http://xuite.net/calla0430
# 酪梨麵包
# 2016/9/8 早餐因為要搭一早(7:27)的高鐵到高雄，前一晚一定得先做好早餐，麵包是最簡單的選擇。為了將流程拍下，在做了一次小熱狗麵包。不過麵團不同，加了酪梨。麵團：高筋麵粉
# 550g、酪梨
# http://blog.xuite.net/julie.tu/twblog/450493953
# http://blog.xuite.net/julie.tu/twblog/450493953/cover.jpg
# Julie
# http://xuite.net/julie.tu
# 蜂蜜玉米麵包
# 第一次揉捏蜂蜜玉米麵包時散發的香氣，我仍然記憶。近來夏夏愛吃玉米麵，冰箱總冷藏一盒已開罐的玉米粒，做起這款麵包來特別方便。那天麵包出爐時已傍晚，夏夏從午寐起醒來，他賴在地墊上吃一口蜂蜜玉米麵包
# (的
# http://blog.xuite.net/anjagirl/blog/416198023
# http://blog.xuite.net/anjagirl/blog/416198023/cover.jpg
# 安娜
# http://xuite.net/anjagirl
# 玫瑰花型麵包
# 二二八連假最後一天終於不下雨了...依然陰冷的天氣,連續做吐司.花型麵包近期是最愛~網路看見的造型讓我去買素火腿一試...雖然素火腿本身不香,但是麵包依然好吃~小失敗的葡萄乾冰箱餅乾及海苔餅乾
# http://blog.xuite.net/comet.123/wretch1/489118034
# http://blog.xuite.net/comet.123/wretch1/489118034/cover.jpg
# 小星
# http://xuite.net/comet.123
# 香芋麵包
# 芋頭料理變化多！ 今天有點反常？頭暈暈的，腦袋放空.......想不起麵包要整哪種花型？直接偷懶！冷藏中種法製作，530g的麵團直接分成六等分，選最簡易的整型法，我很少做過麵團超過80g加上包餡總
# http://blog.xuite.net/jen168/9669/457208120
# http://blog.xuite.net/jen168/9669/457208120/cover.jpg
# violet
# http://xuite.net/jen168
