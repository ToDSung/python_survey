# %%
import requests
import MySQLdb
from bs4 import BeautifulSoup
import jieba
import jieba.analyse

def remove_values_from_list(the_list, val):
    return [value for value in the_list if value != val]

def get_web_page(url): #原始地址
    time.sleep(0.5)  # 每次爬取前暫停 0.5 秒以免被 PTT 網站判定為大量惡意爬取
    resp = requests.get(
        url=url,
        cookies={'over18': '1'}
    )
    return resp.text

jieba.set_dictionary('dict.txt.big')

conn = MySQLdb.connect(host="localhost", user="root", passwd="", db="python",charset='utf8')#連結資料庫
cur = conn.cursor()
cur.execute("SELECT search_href,id,search_title FROM xuite")
results = cur.fetchall()


for record in results: 
    db_url = record[0]
    xuite_id= record[1]
    title=record[2]
    title_list=jieba.lcut(title,cut_all=False)
    print(title_list)
    
    print (db_url)

    res=requests.get(db_url)
    res.encoding='utf-8'
    soup = BeautifulSoup (res.text, "html5lib")
    #內文
    main_article = soup.select('#content_all')   
    sentence=main_article[0].select('span')
    total_count=0
    total_article_count=0
    for line in sentence:

        line2=line.text.strip()
        words=jieba.lcut(line2, cut_all=False)
        s1 = set(title_list)
        s2 = set(words)
        article_count=len(s2)
        total_article_count=total_article_count+article_count
        intersection=s1.intersection(s2)
        count=len(intersection)
        total_count=total_count+count
    print(total_article_count)
    print(total_count)
    print(format(total_count/total_article_count,'0.1%'))
# Out:
# Building prefix dict from C:\Users\wlunareve\python\dict.txt.big ...
# Loading model from cache C:\Users\WLUNAR~1\AppData\Local\Temp\jieba.ube0c4e67d291f94013d7023df2b3161e.cache
# Loading model cost 1.467 seconds.
# Prefix dict has been built succesfully.
# ['「', '捷運', '：', '西門町', '」', ' ', '麵', '包', '廚房']
# http://blog.xuite.net/kellychen6012003/twblog1/454326352
# 0
# 0
# ['蘿莉兔', '愛麗娜', '連載', '四格', '漫畫', '第', '77', '回', ':', '偷吃', '了', '麵', '包']
# http://blog.xuite.net/loveshue2004/ls/457839678
# 0
# 0
# ['【', '沙宣', 'VS', '】', '32', '毫米', '陶瓷', '捲髮', '夾', 'VSCD219SW', ' ', '凝膠', '清潔液']
# http://blog.xuite.net/nud26wd17g/blog/492324830
# 257
# 21
# ['MOMO', '購物', '限時', ' ', '【', 'Ecovacs', '】', 'D45', '濾網', ' ', '國際', '牌', '變頻', '冰']
# http://blog.xuite.net/iupnkaqqfr/blog/493689191
# 269
# 19
# ['MOMO', '購物', ' ', '心得', '推薦', ' ', '【', 'Biore', '】', '含水', '防曬', '清', '透水', '凝露', ' ', 'P']
# http://blog.xuite.net/ayk35nq84y/blog/494313351
# 356
# 30
# ['MOMO', '購物', ' ', '心得', '推薦', ' ', '【', '美娜', '圖塔', '】', '有機', '橄欖', '清爽', '身體', '乳', '250']
# http://blog.xuite.net/ejv25xt80o/blog/494624234
# 282
# 28
# ['MOMO', '購物', ' ', '推薦', '分享', '睡', '之', '寶', 'LED', '強力', '吸入式', '環保', '靜音', '捕', '蚊器', '驚']
# http://blog.xuite.net/kygf0vwbn7/blog/493610514
# 299
# 35
# ['MOMO', '購物', '限時', ' ', '【', 'burner', '倍熱', '】', '休足', '漫步', '霜', '2', '瓶', '特惠', '組', '(']
# http://blog.xuite.net/symv973j7p/blog/494225843
# 506
# 44
# ['MOMO', '購物', '限時', ' ', '【', '神燈', '咖啡', '】', '義式', '綜合', ' ', 'Espresso', ' ', 'B']
# http://blog.xuite.net/ejy3mjag1p/blog/494120650
# 826
# 47
# ['台灣', '樂天', '市場', ' ', '心得', '文甲珍', ' ', '雙人', '-', '單人', '恆溫', '電毯', ' ', 'NHB', '-', '300']
# http://blog.xuite.net/bpy6lgxwss/blog/496156495
# 290
# 32
# ['台灣', '樂天', '市場', ' ', '好物', '推薦', 'LG', ' ', 'G', ' ', 'Pad', ' ', '8.3', ' ', 'V500', ' ', '原']
# http://blog.xuite.net/fwj21bs65q/blog/495662167
# 292
# 32
# ['心得', '開箱', '文', ' ', '台灣', '樂天', '市場', 'PHILIPS', ' ', '飛利浦', ' ', '豆漿機', ' ', 'HD']
# http://blog.xuite.net/slqsqidocx/blog/495734238
# 285
# 26
# ['台灣', '樂天', '市場', ' ', '好物', '推薦', '【', '怡悅', 'HEPA', '濾心', '】', ' ', '適用', '17400', '-']
# http://blog.xuite.net/qus824fsx2/blog/498217939
# 298
# 36
# ['《', '自然', '觀察', '》', '20160511', '熱帶雨林', '的', '生物']
# http://blog.xuite.net/kk8577/03/412609841
# 868
# 19
# ['MOMO', '購物', ' ', '最新', '使用', '心得', '【', '飛利浦', '】', '拔式', '絲滑', '美體', '刀', 'HP654']
# http://blog.xuite.net/ienjrr9b9l/blog/495130567
# 1044
# 56
# ['123']
# http://blog.xuite.net/a1968tw/1117/492488461
# 0
# 0
# ['123']
# http://blog.xuite.net/f714105/blog/495746049
# 0
# 0
# ['123']
# http://blog.xuite.net/chtcloud866564/blog/481648584
# 0
# 0
# ['【', 'OPI', '】', '可口可樂', '限量', '聯名', '系列', '．', '歡樂', '雙倍', '(', 'NLC13', ')', ' ', '○', '好']
# http://blog.xuite.net/li3r7m/blog/494910035
# 4
# 1
# ['123']
# http://blog.xuite.net/a1968tw/1117/492488461
# 0
# 0
# ['123']
# http://blog.xuite.net/f714105/blog/495746049
# 0
# 0
# ['123']
# http://blog.xuite.net/chtcloud866564/blog/481648584
# 0
# 0
# ['2016', '年', '高雄', '旅展']
# http://blog.xuite.net/h012123/wretch/434198882
# 0
# 0
# ['茗', '品茶', ' ', '販賣機']
# http://blog.xuite.net/h012123/wretch/420959315
# 0
# 0
# ['高雄', '鼓山', '-', '海之冰', '(', '大碗', '公冰', '創始', '店', ')']
# http://blog.xuite.net/h012123/wretch/424827070
# 0
# 0
# ['力大', '牛排']
# http://blog.xuite.net/h012123/wretch/446775789
# 0
# 0
# ['水野堂', '日式', '炸豬', '排定', '食']
# http://blog.xuite.net/h012123/wretch/436446521
# 0
# 0
# ['西子灣', '福泉', '水果', '雪花', '冰']
# http://blog.xuite.net/h012123/wretch/437767486
# 0
# 0
# ['新光', '高中']
# http://blog.xuite.net/h012123/wretch/425800122
# 0
# 0
# ['迴轉', '壽司', 'あ', 'っ', 'ぱ', 'れ', ' ', '-', ' ', 'appare']
# http://blog.xuite.net/h012123/wretch/450977820
# 0
# 0
# ['南科', '藝術', '季', ' ', '~', '~', '高雄', '園區', '趴', '趴', 'GO', '!', '送', '好禮', '活動']
# http://blog.xuite.net/kindergarten1999/wretch/458634203
# 0
# 0
# ['桌子']
# http://blog.xuite.net/chfang0222/wretch/452565951
# 39
# 0
# ['日花', '不到', '3', '百', ' ', '高雄', '三餐', '超澎派', '!']
# http://blog.xuite.net/morenoiu81074/blog/445519712
# 0
# 0
# ['【', 'REBLOG', '】', 'HATTER', ' ', '-', ' ', 'PANDORAS', ' ', 'BOX']
# http://blog.xuite.net/st8770b/wretch/432628811
# 1934
# 21
