# %%
import MySQLdb
import requests
from bs4 import BeautifulSoup

conn = MySQLdb.connect(host="localhost", user="root", passwd="", db="python",charset='utf8')#連結資料庫
cur = conn.cursor()
sqli = "insert into indexxuite (tag,search_title,search_author,search_href,article_picture) values (%s,%s,%s,%s,%s)" #選擇資料表


tag_list=['food','travel']
url_list=[15,17]


for topic in range(1,2):
    
    for page in range(1,6):
        url='http://www.a.blog.xuite.net/new_index.php?type=put_list_roller&tag_id='+repr(url_list[topic])+'&p='+repr(page)
        res=requests.get(url)
        res.encoding='utf-8'
        soup=BeautifulSoup (res.text,"lxml")

        for imgs in soup.select('.p1'):
            #文章圖片
            article_picture=imgs.find('img').get('src')
            #網址
            search_href=imgs.find('a').get('href')
            res2=requests.get(search_href)
            res2.encoding='utf-8'
            soup2=BeautifulSoup (res2.text,"lxml")
            article= soup2.select('.ArticleContent')
            #標題
            search_title=article[0].select('.titlename')[0].text
            hrefsplit=search_href.split('/')
            print(search_title)
            #作者
            search_author=hrefsplit[3]
            #作者網址
            #author_href='http://xuite.net/'+search_author
            cur.execute(sqli,(tag_list[topic],search_title,search_author,search_href,article_picture)) #存入資料庫    
            conn.commit()
           

cur.close() #斷開連結
conn.close()
# Out:
# 台東延平●武陵部落●布農族山野獨家美味搶先嘗/耆老講解部落時令/廚娘達人大現身
# 【旅行中的視界】台北陽明山‧七星山主東峰登山步道
# 韓國NEOFLAM鍋具●Retro系列浪漫粉紅鍋限量款●粉領族味蕾親密戀人/好鍋具好心情之天天開伙去/有影片【體驗】
# 澎湖一日遊手機隨手拍(2017.5.2)
# 台北內湖●堤諾比薩Tino's Pizza Café(內湖店)●與瓦薩披薩系出同門/超好吃連鎖披薩
# 2016法國遊記33~聖米歇爾山修道院
# 【旅行中的視界】宜蘭太平山‧翠峰湖環山步道
# 943報好康-加拿大航空 台北直飛溫哥華 來回含稅$21797 NT起
# 【旅行中的視界】宜蘭大同‧松羅國家步道
# 台北松山●QB HOUSE(松山車站店)●日本專業連鎖只"剪髮"/每次300元
# 台北松山●梁家苦茶●唐山老師傅26種秘方熬煮12小時/創立於民國60年/南松市場老店
# 2016法國遊記32~探訪聖米歇爾山
# 【露營碎念】露營流行語之你能負責嗎？
# 【雨天正好眠】苗栗泰安‧逸視界露營區
# 943報好康-飛南非便宜機票精選-同場加映非洲廉航fastjet
# 【露營碎念】為了露營，還是為了五星級衛浴
# 【邀約】台東延平●武陵部落●山谷間的浮世情壞/MAPASADU布谷拉夫/台東部落工作假期
# 【露營裝備】迪卡儂3人加大通風兩秒帳 QUECHUA 2 Seconds XL AIR 3
# 2016澳門4日遊11~新葡京8餐廳超可愛港點
# 【露營裝備】BLACKICE 黑冰 G400 羽絨睡袋（木乃伊式）
# 台北松山●竹村居酒屋(中坡店)●我可能不會愛你之但我愛美食/燒烤火侯得宜/氣泡水果酒推薦
# 【露營裝備開箱】妙管家 4.0Kw高功率電子點火瓦斯爐~防風、熄火自動點火/露營必備
# 【四月白雪】新竹五峰‧哈勇露營區
# 台北中山●河田咖啡食堂●煎魚料理新鮮可期/CP值超高商業午餐/現點現做值得推薦
