# %%
import requests
from bs4 import BeautifulSoup

ptt_url = 'https://www.ptt.cc/'
article_list_information=[]

index_page_source = requests.get(
    'https://www.ptt.cc/bbs/Gossiping/index.html', cookies={'over18': '1'})
soup = BeautifulSoup(index_page_source.text, 'lxml')
today=soup.select('div[class="date"]')[0].text

pages=1
while pages:
    print('目前正在爬取第{}頁'.format(pages))
    old_index =  (ptt_url+soup.select('a[class="btn wide"]')[1]['href'])
    index_page_source = requests.get(
    old_index, cookies={'over18': '1'})
    soup = BeautifulSoup(index_page_source.text, 'lxml')
    articles_list = soup.select('div[class="r-list-container action-bar-margin bbs-screen"]')
    for article in articles_list[0].select('div[class="r-ent"]'):
        if article.a:
            push_boo = article.select('div[class="nrec"]')[0].text
            title = article.a.text
            page_url = (ptt_url + article.a['href'])
            date = article.select('div[class="date"]')[0].text

            if today == date:  
                article_list_information.append([push_boo, title, page_url, date])
            else:
                break
    pages +=1
    
    print(date)
    if today == date:  
        pass
    else:
        print('已爬取完成')
        break
return article_list_information
# Out:
# 目前正在爬取第1頁
#  5/09
# 目前正在爬取第2頁
#  5/09
# 目前正在爬取第3頁
#  5/09
# 目前正在爬取第4頁
#  5/09
# 目前正在爬取第5頁
#  5/09
# 目前正在爬取第6頁
#  5/09
# 目前正在爬取第7頁
#  5/09
# 目前正在爬取第8頁
#  5/09
# 目前正在爬取第9頁
#  5/09
# 目前正在爬取第10頁
#  5/09
# 目前正在爬取第11頁
#  5/09
# 目前正在爬取第12頁
#  5/09
# 目前正在爬取第13頁
#  5/09
# 目前正在爬取第14頁
#  5/09
# 目前正在爬取第15頁
#  5/09
# 目前正在爬取第16頁
#  5/09
# 目前正在爬取第17頁
#  5/09
# 目前正在爬取第18頁
#  5/09
# 目前正在爬取第19頁
#  5/09
# 目前正在爬取第20頁
#  5/09
# 目前正在爬取第21頁
#  5/09
# 目前正在爬取第22頁
#  5/09
# 目前正在爬取第23頁
#  5/09
# 目前正在爬取第24頁
#  5/09
# 目前正在爬取第25頁
#  5/09
# 目前正在爬取第26頁
#  5/09
# 目前正在爬取第27頁
#  5/09
# 目前正在爬取第28頁
#  5/09
# 目前正在爬取第29頁
#  5/09
# 目前正在爬取第30頁
#  5/09
# 目前正在爬取第31頁
#  5/09
# 目前正在爬取第32頁
#  5/09
# 目前正在爬取第33頁
#  5/09
# 目前正在爬取第34頁
#  5/09
# 目前正在爬取第35頁
#  5/09
# 目前正在爬取第36頁
#  5/09
# 目前正在爬取第37頁
#  5/09
# 目前正在爬取第38頁
#  5/09
# 目前正在爬取第39頁
#  5/09
# 目前正在爬取第40頁
#  5/09
# 目前正在爬取第41頁
#  5/09
# 目前正在爬取第42頁
#  5/09
# 目前正在爬取第43頁
#  5/09
# 目前正在爬取第44頁
#  5/09
# 目前正在爬取第45頁
#  5/09
# 目前正在爬取第46頁
#  5/09
# 目前正在爬取第47頁
#  5/09
# 目前正在爬取第48頁
#  5/09
# 目前正在爬取第49頁
#  5/09
# 目前正在爬取第50頁
#  5/09
# 目前正在爬取第51頁
#  5/09
# 目前正在爬取第52頁
#  5/09
# 目前正在爬取第53頁
#  5/09
# 目前正在爬取第54頁
#  5/09
# 目前正在爬取第55頁
#  5/09
# 目前正在爬取第56頁
#  5/09
# 目前正在爬取第57頁
#  5/09
# 目前正在爬取第58頁
#  5/09
# 目前正在爬取第59頁
#  5/09
# 目前正在爬取第60頁
#  5/09
# 目前正在爬取第61頁
#  5/09
# 目前正在爬取第62頁
#  5/09
# 目前正在爬取第63頁
#  5/09
# 目前正在爬取第64頁
#  5/09
# 目前正在爬取第65頁
#  5/09
# 目前正在爬取第66頁
#  5/09
# 目前正在爬取第67頁
#  5/09
# 目前正在爬取第68頁
#  5/09
# 目前正在爬取第69頁
#  5/09
# 目前正在爬取第70頁
#  5/09
# 目前正在爬取第71頁
#  5/09
# 目前正在爬取第72頁
#  5/09
# 目前正在爬取第73頁
#  5/09
# 目前正在爬取第74頁
#  5/09
# 目前正在爬取第75頁
#  5/09
# 目前正在爬取第76頁
#  5/08
# 已爬取完成

# %%
print(article_list_information)
# Out:
# [['1', '[問卦] 中華安康扶貧關懷協會 正派嗎？', 'https://www.ptt.cc//bbs/Gossiping/M.1525848911.A.0E8.html', ' 5/09'], ['', '[問卦] 電信資費到底是哪個時間點辦才好？', 'https://www.ptt.cc//bbs/Gossiping/M.1525848925.A.4A8.html', ' 5/09'], ['', '[問卦] 籃球場有小蘿莉腫摸辦？', 'https://www.ptt.cc//bbs/Gossiping/M.1525848960.A.C71.html', ' 5/09'], ['', '[爆卦] 桃園市議員母親節送活體動物！？', 'https://www.ptt.cc//bbs/Gossiping/M.1525848967.A.A4C.html', ' 5/09'], ['17', 'Re: [新聞] 網友別亂罵！吳崢說：我本來就免役', 'https://www.ptt.cc//bbs/Gossiping/M.1525848971.A.9C0.html', ' 5/09'], ['', '[問卦] 有沒有中華電信對身心障礙最好的八卦？', 'https://www.ptt.cc//bbs/Gossiping/M.1525848991.A.7DD.html', ' 5/09'], ['50', '[爆卦] 翟本喬在中天嗆DPP在台大就是想擺自己人', 'https://www.ptt.cc//bbs/Gossiping/M.1525849011.A.126.html', ' 5/09'], ['', 'Re: [爆卦] 三普退出伊朗核協議啦', 'https://www.ptt.cc//bbs/Gossiping/M.1525849016.A.96E.html', ' 5/09'], ['5', '[問卦] 板上有會併排停車的機歪鄉民嗎', 'https://www.ptt.cc//bbs/Gossiping/M.1525849082.A.D9A.html', ' 5/09'], ['6', '[問卦]洗頭小妹洗到肥宅的頭在想什麼？', 'https://www.ptt.cc//bbs/Gossiping/M.1525849087.A.010.html', ' 5/09'], ['3', 'Re: [ＦＢ] 梁文傑 民進黨不接受這種要不要隨你', 'https://www.ptt.cc//bbs/Gossiping/M.1525849138.A.B29.html', ' 5/09'], ['', 'Re: [問卦] TOP被TOP追會覺得噁心嗎', 'https://www.ptt.cc//bbs/Gossiping/M.1525849223.A.35D.html', ' 5/09'], ['1', '[問卦] 有沒有中華客服怎麼打都打不進去的八卦', 'https://www.ptt.cc//bbs/Gossiping/M.1525849287.A.53F.html', ' 5/09'], ['1', 'Re: [新聞] 網友別亂罵！吳崢說：我本來就免役', 'https://www.ptt.cc//bbs/Gossiping/M.1525849344.A.5CC.html', ' 5/09'], ['58', '[新聞] 藍營的最差情況？她說：棄丁保柯？', 'https://www.ptt.cc//bbs/Gossiping/M.1525849365.A.C84.html', ' 5/09'], ['5', '[問卦] 遇到酒駕怎麼辦？？？', 'https://www.ptt.cc//bbs/Gossiping/M.1525849367.A.A90.html', ' 5/09'], ['9', '[新聞] 領百萬掉十萬！男拾金不昧送警局\u3000謙虛婉', 'https://www.ptt.cc//bbs/Gossiping/M.1525849503.A.69B.html', ' 5/09'], ['8', '[新聞] IMF：今年印度經